# %% [markdown]
# STAT 453: Deep Learning (Spring 2021)
# Instructor: Sebastian Raschka (sraschka@wisc.edu)
#
# Course website: http://pages.stat.wisc.edu/~sraschka/teaching/stat453-ss2021/
# GitHub repository: https://github.com/rasbt/stat453-deep-learning-ss21
#
# ---

# %%
# %load_ext watermark
# %watermark -a 'Sebastian Raschka' -v -p torch
# Out:
# Author: Sebastian Raschka
#
# Python implementation: CPython
# Python version       : 3.8.8
# IPython version      : 7.21.0
#
# torch: 1.8.0

# %% [markdown]
# # All-Convolutional Net on Cifar-10

# %% [markdown]
# ## Imports

# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# %%
# From local helper files
from helper_evaluation import set_all_seeds, set_deterministic, compute_confusion_matrix
from helper_train import train_model
from helper_plotting import plot_training_loss, plot_accuracy, show_examples, plot_confusion_matrix
from helper_dataset import get_dataloaders_cifar10, UnNormalize

# %% [markdown]
# ## Settings and Dataset

# %%
##########################
### SETTINGS
##########################

RANDOM_SEED = 123
BATCH_SIZE = 256
NUM_EPOCHS = 50
DEVICE = torch.device('cuda:2' if torch.cuda.is_available() else 'cpu')

# %%
set_all_seeds(RANDOM_SEED)
#set_deterministic()

# %%
##########################
### CIFAR-10 DATASET
##########################

train_transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((70, 70)),
    torchvision.transforms.RandomCrop((64, 64)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                      ])

test_transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((70, 70)),        
    torchvision.transforms.CenterCrop((64, 64)),            
    torchvision.transforms.ToTensor(),                
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])




train_loader, valid_loader, test_loader = get_dataloaders_cifar10(
    batch_size=BATCH_SIZE,
    validation_fraction=0.1,
    train_transforms=train_transforms,
    test_transforms=test_transforms,
    num_workers=2)

# Checking the dataset
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    print('Class labels of 10 examples:', labels[:10])
    break
# Out:
# Files already downloaded and verified
# Image batch dimensions: torch.Size([256, 3, 64, 64])
# Image label dimensions: torch.Size([256])
# Class labels of 10 examples: tensor([4, 7, 4, 6, 2, 6, 9, 7, 3, 0])

# %% [markdown]
# ## Model

# %%
##########################
### MODEL
##########################


class AllConvNet(torch.nn.Module):

    def __init__(self, num_classes):
        super().__init__()
        
        self.net = torch.nn.Sequential(
                      torch.nn.Conv2d(in_channels=3,
                                      out_channels=16,
                                      kernel_size=(3, 3),
                                      stride=(1, 1),
                                      padding=1,
                                      bias=False),
                      torch.nn.BatchNorm2d(16),
                      torch.nn.ReLU(inplace=True),
                      torch.nn.Conv2d(in_channels=16,
                                      out_channels=16,
                                      kernel_size=(3, 3),
                                      stride=(2, 2),
                                      padding=1,
                                      bias=False),   
                      torch.nn.BatchNorm2d(16),
                      torch.nn.ReLU(inplace=True),
                      torch.nn.Conv2d(in_channels=16,
                                      out_channels=32,
                                      kernel_size=(3, 3),
                                      stride=(1, 1),
                                      padding=1,
                                      bias=False),        
                      torch.nn.BatchNorm2d(32),
                      torch.nn.ReLU(inplace=True),                        
                      torch.nn.Conv2d(in_channels=32,
                                      out_channels=32,
                                      kernel_size=(3, 3),
                                      stride=(2, 2),
                                      padding=1,
                                      bias=False),      
                      torch.nn.BatchNorm2d(32),
                      torch.nn.ReLU(inplace=True),       
                      torch.nn.Conv2d(in_channels=32,
                                      out_channels=64,
                                      kernel_size=(3, 3),
                                      stride=(1, 1),
                                      padding=1,
                                      bias=False),   
                      torch.nn.BatchNorm2d(64),
                      torch.nn.ReLU(inplace=True),
                      torch.nn.Conv2d(in_channels=64,
                                      out_channels=64,
                                      kernel_size=(3, 3),
                                      stride=(2, 2),
                                      padding=1,
                                      bias=False),     
                      torch.nn.BatchNorm2d(64),
                      torch.nn.ReLU(inplace=True),
                      torch.nn.Conv2d(in_channels=64,
                                      out_channels=num_classes,
                                      kernel_size=(3, 3),
                                      stride=(1, 1),
                                      padding=1,
                                      bias=False),    
                      torch.nn.BatchNorm2d(10),
                      torch.nn.ReLU(inplace=True),
                      torch.nn.AdaptiveAvgPool2d(1),
                      torch.nn.Flatten()
    )


    def forward(self, x):
        
        x = self.net(x)
        #probas = torch.softmax(x, dim=1)
        return x

# %%
model = AllConvNet(num_classes=10)

model = model.to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), momentum=0.9, lr=0.1)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,
                                                       factor=0.1,
                                                       mode='max',
                                                       verbose=True)

minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=NUM_EPOCHS,
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=DEVICE,
    scheduler=scheduler,
    scheduler_on='valid_acc',
    logging_interval=100)

plot_training_loss(minibatch_loss_list=minibatch_loss_list,
                   num_epochs=NUM_EPOCHS,
                   iter_per_epoch=len(train_loader),
                   results_dir=None,
                   averaging_iterations=200)
plt.show()

plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([60, 100])
plt.show()
# Out:
# Epoch: 001/050 | Batch 0000/0175 | Loss: 2.3469
# Epoch: 001/050 | Batch 0100/0175 | Loss: 1.5787
# Epoch: 001/050 | Train: 44.83% | Validation: 45.10%
# Time elapsed: 0.88 min
# Epoch: 002/050 | Batch 0000/0175 | Loss: 1.2846
# Epoch: 002/050 | Batch 0100/0175 | Loss: 1.1803
# Epoch: 002/050 | Train: 55.25% | Validation: 54.58%
# Time elapsed: 1.72 min
# Epoch: 003/050 | Batch 0000/0175 | Loss: 1.0080
# Epoch: 003/050 | Batch 0100/0175 | Loss: 0.9030
# Epoch: 003/050 | Train: 67.30% | Validation: 68.42%
# Time elapsed: 2.61 min
# Epoch: 004/050 | Batch 0000/0175 | Loss: 0.9473
# Epoch: 004/050 | Batch 0100/0175 | Loss: 0.8610
# Epoch: 004/050 | Train: 63.72% | Validation: 63.06%
# Time elapsed: 3.49 min
# Epoch: 005/050 | Batch 0000/0175 | Loss: 0.7824
# Epoch: 005/050 | Batch 0100/0175 | Loss: 0.7424
# Epoch: 005/050 | Train: 66.91% | Validation: 66.82%
# Time elapsed: 4.37 min
# Epoch: 006/050 | Batch 0000/0175 | Loss: 0.7429
# Epoch: 006/050 | Batch 0100/0175 | Loss: 0.7136
# Epoch: 006/050 | Train: 73.00% | Validation: 72.04%
# Time elapsed: 5.24 min
# Epoch: 007/050 | Batch 0000/0175 | Loss: 0.7161
# Epoch: 007/050 | Batch 0100/0175 | Loss: 0.6191
# Epoch: 007/050 | Train: 76.30% | Validation: 74.94%
# Time elapsed: 6.13 min
# Epoch: 008/050 | Batch 0000/0175 | Loss: 0.5491
# Epoch: 008/050 | Batch 0100/0175 | Loss: 0.6275
# Epoch: 008/050 | Train: 70.06% | Validation: 69.82%
# Time elapsed: 6.97 min
# Epoch: 009/050 | Batch 0000/0175 | Loss: 0.4904
# Epoch: 009/050 | Batch 0100/0175 | Loss: 0.5724
# Epoch: 009/050 | Train: 74.06% | Validation: 73.44%
# Time elapsed: 7.84 min
# Epoch: 010/050 | Batch 0000/0175 | Loss: 0.5670
# Epoch: 010/050 | Batch 0100/0175 | Loss: 0.5895
# Epoch: 010/050 | Train: 78.13% | Validation: 75.66%
# Time elapsed: 8.71 min
# Epoch: 011/050 | Batch 0000/0175 | Loss: 0.6729
# Epoch: 011/050 | Batch 0100/0175 | Loss: 0.5676
# Epoch: 011/050 | Train: 78.93% | Validation: 76.82%
# Time elapsed: 9.57 min
# Epoch: 012/050 | Batch 0000/0175 | Loss: 0.5231
# Epoch: 012/050 | Batch 0100/0175 | Loss: 0.6256
# Epoch: 012/050 | Train: 80.56% | Validation: 78.42%
# Time elapsed: 10.46 min
# Epoch: 013/050 | Batch 0000/0175 | Loss: 0.4809
# Epoch: 013/050 | Batch 0100/0175 | Loss: 0.5378
# Epoch: 013/050 | Train: 77.56% | Validation: 75.16%
# Time elapsed: 11.34 min
# Epoch: 014/050 | Batch 0000/0175 | Loss: 0.4408
# Epoch: 014/050 | Batch 0100/0175 | Loss: 0.5065
# Epoch: 014/050 | Train: 78.66% | Validation: 76.54%
# Time elapsed: 12.19 min
# Epoch: 015/050 | Batch 0000/0175 | Loss: 0.5678
# Epoch: 015/050 | Batch 0100/0175 | Loss: 0.4340
# Epoch: 015/050 | Train: 82.04% | Validation: 79.60%
# Time elapsed: 13.07 min
# Epoch: 016/050 | Batch 0000/0175 | Loss: 0.5311
# Epoch: 016/050 | Batch 0100/0175 | Loss: 0.5775
# Epoch: 016/050 | Train: 78.97% | Validation: 76.36%
# Time elapsed: 13.95 min
# Epoch: 017/050 | Batch 0000/0175 | Loss: 0.4131
# Epoch: 017/050 | Batch 0100/0175 | Loss: 0.3943
# Epoch: 017/050 | Train: 83.01% | Validation: 79.38%
# Time elapsed: 14.81 min
# Epoch: 018/050 | Batch 0000/0175 | Loss: 0.4910
# Epoch: 018/050 | Batch 0100/0175 | Loss: 0.4898
# Epoch: 018/050 | Train: 81.44% | Validation: 78.72%
# Time elapsed: 15.70 min
# Epoch: 019/050 | Batch 0000/0175 | Loss: 0.5380
# Epoch: 019/050 | Batch 0100/0175 | Loss: 0.4044
# Epoch: 019/050 | Train: 83.10% | Validation: 79.94%
# Time elapsed: 16.57 min
# Epoch: 020/050 | Batch 0000/0175 | Loss: 0.4142
# Epoch: 020/050 | Batch 0100/0175 | Loss: 0.4912
# Epoch: 020/050 | Train: 83.82% | Validation: 80.10%
# Time elapsed: 17.45 min
# Epoch: 021/050 | Batch 0000/0175 | Loss: 0.3791
# Epoch: 021/050 | Batch 0100/0175 | Loss: 0.4392
# Epoch: 021/050 | Train: 84.56% | Validation: 80.42%
# Time elapsed: 18.30 min
# Epoch: 022/050 | Batch 0000/0175 | Loss: 0.3710
# Epoch: 022/050 | Batch 0100/0175 | Loss: 0.4578
# Epoch: 022/050 | Train: 84.55% | Validation: 80.50%
# Time elapsed: 19.14 min
# Epoch: 023/050 | Batch 0000/0175 | Loss: 0.4107
# Epoch: 023/050 | Batch 0100/0175 | Loss: 0.3710
# Epoch: 023/050 | Train: 81.74% | Validation: 78.76%
# Time elapsed: 19.93 min
# Epoch: 024/050 | Batch 0000/0175 | Loss: 0.3589
# Epoch: 024/050 | Batch 0100/0175 | Loss: 0.4011
# Epoch: 024/050 | Train: 83.33% | Validation: 79.50%
# Time elapsed: 20.76 min
# Epoch: 025/050 | Batch 0000/0175 | Loss: 0.3515
# Epoch: 025/050 | Batch 0100/0175 | Loss: 0.4230
# Epoch: 025/050 | Train: 86.86% | Validation: 81.68%
# Time elapsed: 21.58 min
# Epoch: 026/050 | Batch 0000/0175 | Loss: 0.4341
# Epoch: 026/050 | Batch 0100/0175 | Loss: 0.3257
# Epoch: 026/050 | Train: 84.54% | Validation: 80.48%
# Time elapsed: 22.39 min
# Epoch: 027/050 | Batch 0000/0175 | Loss: 0.3114
# Epoch: 027/050 | Batch 0100/0175 | Loss: 0.3392
# Epoch: 027/050 | Train: 84.47% | Validation: 79.88%
# Time elapsed: 23.21 min
# Epoch: 028/050 | Batch 0000/0175 | Loss: 0.3668
# Epoch: 028/050 | Batch 0100/0175 | Loss: 0.5354
# Epoch: 028/050 | Train: 83.47% | Validation: 79.38%
# Time elapsed: 24.01 min
# Epoch: 029/050 | Batch 0000/0175 | Loss: 0.2966
# Epoch: 029/050 | Batch 0100/0175 | Loss: 0.4585
# Epoch: 029/050 | Train: 84.74% | Validation: 80.42%
# Time elapsed: 24.84 min
# Epoch: 030/050 | Batch 0000/0175 | Loss: 0.3192
# Epoch: 030/050 | Batch 0100/0175 | Loss: 0.3577
# Epoch: 030/050 | Train: 87.36% | Validation: 82.78%
# Time elapsed: 25.66 min
# Epoch: 031/050 | Batch 0000/0175 | Loss: 0.4264
# Epoch: 031/050 | Batch 0100/0175 | Loss: 0.3794
# Epoch: 031/050 | Train: 85.94% | Validation: 80.76%
# Time elapsed: 26.49 min
# Epoch: 032/050 | Batch 0000/0175 | Loss: 0.3411
# Epoch: 032/050 | Batch 0100/0175 | Loss: 0.4040
# Epoch: 032/050 | Train: 86.86% | Validation: 81.76%
# Time elapsed: 27.29 min
# Epoch: 033/050 | Batch 0000/0175 | Loss: 0.3130
# Epoch: 033/050 | Batch 0100/0175 | Loss: 0.2982
# Epoch: 033/050 | Train: 86.13% | Validation: 80.94%
# Time elapsed: 28.12 min
# Epoch: 034/050 | Batch 0000/0175 | Loss: 0.3595
# Epoch: 034/050 | Batch 0100/0175 | Loss: 0.3102
# Epoch: 034/050 | Train: 86.43% | Validation: 80.86%
# Time elapsed: 28.93 min
# Epoch: 035/050 | Batch 0000/0175 | Loss: 0.3293
# Epoch: 035/050 | Batch 0100/0175 | Loss: 0.3138
# Epoch: 035/050 | Train: 86.70% | Validation: 81.60%
# Time elapsed: 29.72 min
# Epoch: 036/050 | Batch 0000/0175 | Loss: 0.3819
# Epoch: 036/050 | Batch 0100/0175 | Loss: 0.4457
# Epoch: 036/050 | Train: 88.03% | Validation: 82.78%
# Time elapsed: 30.55 min
# Epoch: 037/050 | Batch 0000/0175 | Loss: 0.2932
# Epoch: 037/050 | Batch 0100/0175 | Loss: 0.3265
# Epoch: 037/050 | Train: 88.17% | Validation: 81.66%
# Time elapsed: 31.37 min
# Epoch: 038/050 | Batch 0000/0175 | Loss: 0.2922
# Epoch: 038/050 | Batch 0100/0175 | Loss: 0.2934
# Epoch: 038/050 | Train: 82.89% | Validation: 77.88%
# Time elapsed: 32.19 min
# Epoch: 039/050 | Batch 0000/0175 | Loss: 0.2860
# Epoch: 039/050 | Batch 0100/0175 | Loss: 0.3131
# Epoch: 039/050 | Train: 86.50% | Validation: 80.84%
# Time elapsed: 33.02 min
# Epoch: 040/050 | Batch 0000/0175 | Loss: 0.3394
# Epoch: 040/050 | Batch 0100/0175 | Loss: 0.2636
# Epoch: 040/050 | Train: 89.24% | Validation: 83.02%
# Time elapsed: 33.85 min
# Epoch: 041/050 | Batch 0000/0175 | Loss: 0.3719
# Epoch: 041/050 | Batch 0100/0175 | Loss: 0.3153
# Epoch: 041/050 | Train: 88.30% | Validation: 82.12%
# Time elapsed: 34.61 min
# Epoch: 042/050 | Batch 0000/0175 | Loss: 0.2902
# Epoch: 042/050 | Batch 0100/0175 | Loss: 0.2877
# Epoch: 042/050 | Train: 88.36% | Validation: 82.18%
# Time elapsed: 35.38 min
# Epoch: 043/050 | Batch 0000/0175 | Loss: 0.2496
# Epoch: 043/050 | Batch 0100/0175 | Loss: 0.3366
# Epoch: 043/050 | Train: 89.67% | Validation: 82.84%
# Time elapsed: 36.14 min
# Epoch: 044/050 | Batch 0000/0175 | Loss: 0.2595
# Epoch: 044/050 | Batch 0100/0175 | Loss: 0.3498
# Epoch: 044/050 | Train: 87.89% | Validation: 81.74%
# Time elapsed: 36.89 min
# Epoch: 045/050 | Batch 0000/0175 | Loss: 0.2683
# Epoch: 045/050 | Batch 0100/0175 | Loss: 0.3336
# Epoch: 045/050 | Train: 89.83% | Validation: 83.04%
# Time elapsed: 37.69 min
# Epoch: 046/050 | Batch 0000/0175 | Loss: 0.2074
# Epoch: 046/050 | Batch 0100/0175 | Loss: 0.3002
# Epoch: 046/050 | Train: 88.86% | Validation: 82.60%
# Time elapsed: 38.45 min
# Epoch: 047/050 | Batch 0000/0175 | Loss: 0.2454
# Epoch: 047/050 | Batch 0100/0175 | Loss: 0.3170
# Epoch: 047/050 | Train: 88.10% | Validation: 81.20%
# Time elapsed: 39.21 min
# Epoch: 048/050 | Batch 0000/0175 | Loss: 0.2673
# Epoch: 048/050 | Batch 0100/0175 | Loss: 0.3335
# Epoch: 048/050 | Train: 89.40% | Validation: 82.68%
# Time elapsed: 39.98 min
# Epoch: 049/050 | Batch 0000/0175 | Loss: 0.3098
# Epoch: 049/050 | Batch 0100/0175 | Loss: 0.3371
# Epoch: 049/050 | Train: 89.54% | Validation: 82.92%
# Time elapsed: 40.75 min
# Epoch: 050/050 | Batch 0000/0175 | Loss: 0.2480
# Epoch: 050/050 | Batch 0100/0175 | Loss: 0.2150
# Epoch: 050/050 | Train: 88.70% | Validation: 81.86%
# Time elapsed: 41.50 min
# Total Training Time: 41.50 min
# Test accuracy 80.67%

# %%
model.cpu()
unnormalizer = UnNormalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
class_dict = {0: 'airplane',
              1: 'automobile',
              2: 'bird',
              3: 'cat',
              4: 'deer',
              5: 'dog',
              6: 'frog',
              7: 'horse',
              8: 'ship',
              9: 'truck'}

show_examples(model=model, data_loader=test_loader, unnormalizer=unnormalizer, class_dict=class_dict)

# %%
mat = compute_confusion_matrix(model=model, data_loader=test_loader, device=torch.device('cpu'))
plot_confusion_matrix(mat, class_names=class_dict.values())
plt.show()
