# %% [markdown]
# STAT 453: Deep Learning (Spring 2021)
# Instructor: Sebastian Raschka (sraschka@wisc.edu)
#
# Course website: http://pages.stat.wisc.edu/~sraschka/teaching/stat453-ss2021/
# GitHub repository: https://github.com/rasbt/stat453-deep-learning-ss21
#
# ---

# %%
# %load_ext watermark
# %watermark -a 'Sebastian Raschka' -v -p torch
# Out:
# Author: Sebastian Raschka
#
# Python implementation: CPython
# Python version       : 3.8.8
# IPython version      : 7.21.0
#
# torch: 1.8.0

# %% [markdown]
# # AlexNet on Cifar-10

# %% [markdown]
# ## Imports

# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# %%
# From local helper files
from helper_evaluation import set_all_seeds, set_deterministic, compute_confusion_matrix
from helper_train import train_model
from helper_plotting import plot_training_loss, plot_accuracy, show_examples, plot_confusion_matrix
from helper_dataset import get_dataloaders_cifar10, UnNormalize

# %% [markdown]
# ## Settings and Dataset

# %%
##########################
### SETTINGS
##########################

RANDOM_SEED = 123
BATCH_SIZE = 256
NUM_EPOCHS = 50
DEVICE = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')

# %%
set_all_seeds(RANDOM_SEED)
#set_deterministic()

# %%
##########################
### MNIST DATASET
##########################

train_transforms = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transforms = torchvision.transforms.Compose([            
    torchvision.transforms.ToTensor(),                
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])


train_loader, valid_loader, test_loader = get_dataloaders_cifar10(
    batch_size=BATCH_SIZE,
    validation_fraction=0.1,
    train_transforms=train_transforms,
    test_transforms=test_transforms,
    num_workers=2)

# Checking the dataset
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    print('Class labels of 10 examples:', labels[:10])
    break
# Out:
# Files already downloaded and verified
# Image batch dimensions: torch.Size([256, 3, 32, 32])
# Image label dimensions: torch.Size([256])
# Class labels of 10 examples: tensor([4, 7, 4, 6, 2, 6, 9, 7, 3, 0])

# %% [markdown]
# ## Model

# %%
class ConvNet(torch.nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.num_classes = num_classes
        self.layers = torch.nn.Sequential(
                torch.nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1),
                torch.nn.BatchNorm2d(32),
                torch.nn.LeakyReLU(0.1, inplace=True),
                #
                torch.nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
                torch.nn.BatchNorm2d(64),
                torch.nn.LeakyReLU(0.1, inplace=True),
                #
                torch.nn.Conv2d(64, 64, kernel_size=3, stride=2, padding=1),
                torch.nn.BatchNorm2d(64),
                torch.nn.LeakyReLU(0.1, inplace=True),
                #
                torch.nn.Flatten(),
                torch.nn.Linear(4096, 128),
                torch.nn.BatchNorm1d(128),
                torch.nn.LeakyReLU(0.1, inplace=True),
                torch.nn.Dropout(0.5),
                #
                torch.nn.Linear(128, num_classes),
                )

    def forward(self, x):
        logits = self.layers(x)
        #probas = torch.softmax(logits, dim=1)
        return logits

# %%
model = ConvNet(num_classes=10)

model = model.to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), momentum=0.9, lr=0.1)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,
                                                       factor=0.1,
                                                       mode='max',
                                                       verbose=True)

minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=NUM_EPOCHS,
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=DEVICE,
    scheduler=scheduler,
    scheduler_on='valid_acc',
    logging_interval=100)

plot_training_loss(minibatch_loss_list=minibatch_loss_list,
                   num_epochs=NUM_EPOCHS,
                   iter_per_epoch=len(train_loader),
                   results_dir=None,
                   averaging_iterations=200)
plt.show()

plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([60, 100])
plt.show()
# Out:
# Epoch: 001/050 | Batch 0000/0175 | Loss: 2.4832
# Epoch: 001/050 | Batch 0100/0175 | Loss: 1.4126
# Epoch: 001/050 | Train: 53.40% | Validation: 53.80%
# Time elapsed: 0.61 min
# Epoch: 002/050 | Batch 0000/0175 | Loss: 1.2073
# Epoch: 002/050 | Batch 0100/0175 | Loss: 1.0672
# Epoch: 002/050 | Train: 63.83% | Validation: 62.38%
# Time elapsed: 1.22 min
# Epoch: 003/050 | Batch 0000/0175 | Loss: 1.0231
# Epoch: 003/050 | Batch 0100/0175 | Loss: 0.9564
# Epoch: 003/050 | Train: 71.10% | Validation: 67.96%
# Time elapsed: 1.85 min
# Epoch: 004/050 | Batch 0000/0175 | Loss: 0.8356
# Epoch: 004/050 | Batch 0100/0175 | Loss: 0.9826
# Epoch: 004/050 | Train: 71.95% | Validation: 68.02%
# Time elapsed: 2.47 min
# Epoch: 005/050 | Batch 0000/0175 | Loss: 0.8070
# Epoch: 005/050 | Batch 0100/0175 | Loss: 0.8272
# Epoch: 005/050 | Train: 76.11% | Validation: 70.52%
# Time elapsed: 3.09 min
# Epoch: 006/050 | Batch 0000/0175 | Loss: 0.7483
# Epoch: 006/050 | Batch 0100/0175 | Loss: 0.6512
# Epoch: 006/050 | Train: 79.70% | Validation: 72.00%
# Time elapsed: 3.70 min
# Epoch: 007/050 | Batch 0000/0175 | Loss: 0.7219
# Epoch: 007/050 | Batch 0100/0175 | Loss: 0.7354
# Epoch: 007/050 | Train: 82.92% | Validation: 74.10%
# Time elapsed: 4.33 min
# Epoch: 008/050 | Batch 0000/0175 | Loss: 0.6432
# Epoch: 008/050 | Batch 0100/0175 | Loss: 0.6682
# Epoch: 008/050 | Train: 82.95% | Validation: 74.18%
# Time elapsed: 4.97 min
# Epoch: 009/050 | Batch 0000/0175 | Loss: 0.4502
# Epoch: 009/050 | Batch 0100/0175 | Loss: 0.6992
# Epoch: 009/050 | Train: 84.36% | Validation: 73.18%
# Time elapsed: 5.58 min
# Epoch: 010/050 | Batch 0000/0175 | Loss: 0.5674
# Epoch: 010/050 | Batch 0100/0175 | Loss: 0.6181
# Epoch: 010/050 | Train: 84.79% | Validation: 72.88%
# Time elapsed: 6.20 min
# Epoch: 011/050 | Batch 0000/0175 | Loss: 0.5579
# Epoch: 011/050 | Batch 0100/0175 | Loss: 0.5441
# Epoch: 011/050 | Train: 88.22% | Validation: 74.24%
# Time elapsed: 6.82 min
# Epoch: 012/050 | Batch 0000/0175 | Loss: 0.4655
# Epoch: 012/050 | Batch 0100/0175 | Loss: 0.4386
# Epoch: 012/050 | Train: 90.06% | Validation: 75.28%
# Time elapsed: 7.44 min
# Epoch: 013/050 | Batch 0000/0175 | Loss: 0.3944
# Epoch: 013/050 | Batch 0100/0175 | Loss: 0.3938
# Epoch: 013/050 | Train: 90.39% | Validation: 74.30%
# Time elapsed: 8.06 min
# Epoch: 014/050 | Batch 0000/0175 | Loss: 0.4161
# Epoch: 014/050 | Batch 0100/0175 | Loss: 0.3678
# Epoch: 014/050 | Train: 92.17% | Validation: 74.98%
# Time elapsed: 8.70 min
# Epoch: 015/050 | Batch 0000/0175 | Loss: 0.2873
# Epoch: 015/050 | Batch 0100/0175 | Loss: 0.4583
# Epoch: 015/050 | Train: 93.45% | Validation: 74.64%
# Time elapsed: 9.32 min
# Epoch: 016/050 | Batch 0000/0175 | Loss: 0.3048
# Epoch: 016/050 | Batch 0100/0175 | Loss: 0.3105
# Epoch: 016/050 | Train: 93.53% | Validation: 74.80%
# Time elapsed: 9.93 min
# Epoch: 017/050 | Batch 0000/0175 | Loss: 0.2647
# Epoch: 017/050 | Batch 0100/0175 | Loss: 0.4513
# Epoch: 017/050 | Train: 94.40% | Validation: 74.48%
# Time elapsed: 10.55 min
# Epoch: 018/050 | Batch 0000/0175 | Loss: 0.3731
# Epoch: 018/050 | Batch 0100/0175 | Loss: 0.3473
# Epoch: 018/050 | Train: 95.32% | Validation: 74.74%
# Time elapsed: 11.17 min
# Epoch: 019/050 | Batch 0000/0175 | Loss: 0.2294
# Epoch: 019/050 | Batch 0100/0175 | Loss: 0.3088
# Epoch: 019/050 | Train: 95.60% | Validation: 75.10%
# Time elapsed: 11.80 min
# Epoch: 020/050 | Batch 0000/0175 | Loss: 0.2718
# Epoch: 020/050 | Batch 0100/0175 | Loss: 0.2993
# Epoch: 020/050 | Train: 95.08% | Validation: 74.08%
# Time elapsed: 12.42 min
# Epoch: 021/050 | Batch 0000/0175 | Loss: 0.2880
# Epoch: 021/050 | Batch 0100/0175 | Loss: 0.2527
# Epoch: 021/050 | Train: 96.53% | Validation: 74.92%
# Time elapsed: 13.03 min
# Epoch: 022/050 | Batch 0000/0175 | Loss: 0.2655
# Epoch: 022/050 | Batch 0100/0175 | Loss: 0.2368
# Epoch: 022/050 | Train: 97.30% | Validation: 75.00%
# Time elapsed: 13.66 min
# Epoch: 023/050 | Batch 0000/0175 | Loss: 0.1404
# Epoch: 023/050 | Batch 0100/0175 | Loss: 0.2132
# Epoch: 023/050 | Train: 97.42% | Validation: 75.02%
# Time elapsed: 14.28 min
# Epoch    23: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 024/050 | Batch 0000/0175 | Loss: 0.1571
# Epoch: 038/050 | Train: 99.87% | Validation: 77.60%
# Time elapsed: 23.56 min
# Epoch: 039/050 | Batch 0000/0175 | Loss: 0.0811
# Epoch: 039/050 | Batch 0100/0175 | Loss: 0.0797
# Epoch: 039/050 | Train: 99.89% | Validation: 77.56%
# Time elapsed: 24.18 min
# Epoch: 040/050 | Batch 0000/0175 | Loss: 0.0841
# Epoch: 040/050 | Batch 0100/0175 | Loss: 0.0860
# Epoch: 040/050 | Train: 99.91% | Validation: 77.42%
# Time elapsed: 24.80 min
# Epoch: 041/050 | Batch 0000/0175 | Loss: 0.1128
# Epoch: 041/050 | Batch 0100/0175 | Loss: 0.0515
# Epoch: 041/050 | Train: 99.91% | Validation: 77.08%
# Time elapsed: 25.42 min
# Epoch: 042/050 | Batch 0000/0175 | Loss: 0.0763
# Epoch: 042/050 | Batch 0100/0175 | Loss: 0.0511
# Epoch: 042/050 | Train: 99.92% | Validation: 77.18%
# Time elapsed: 26.04 min
# Epoch: 043/050 | Batch 0000/0175 | Loss: 0.0524
# Epoch: 043/050 | Batch 0100/0175 | Loss: 0.0723
# Epoch: 043/050 | Train: 99.92% | Validation: 77.26%
# Time elapsed: 26.66 min
# Epoch: 044/050 | Batch 0000/0175 | Loss: 0.0761
# Epoch: 044/050 | Batch 0100/0175 | Loss: 0.0700
# Epoch: 044/050 | Train: 99.92% | Validation: 77.32%
# Time elapsed: 27.28 min
# Epoch: 045/050 | Batch 0000/0175 | Loss: 0.0911
# Epoch: 045/050 | Batch 0100/0175 | Loss: 0.0431
# Epoch: 045/050 | Train: 99.94% | Validation: 77.24%
# Time elapsed: 27.91 min
# Epoch: 046/050 | Batch 0000/0175 | Loss: 0.0610
# Epoch: 046/050 | Batch 0100/0175 | Loss: 0.0817
# Epoch: 046/050 | Train: 99.92% | Validation: 76.86%
# Time elapsed: 28.54 min
# Epoch: 047/050 | Batch 0000/0175 | Loss: 0.0461
# Epoch: 047/050 | Batch 0100/0175 | Loss: 0.0412
# Epoch: 047/050 | Train: 99.93% | Validation: 77.48%
# Time elapsed: 29.16 min
# Epoch: 048/050 | Batch 0000/0175 | Loss: 0.0887
# Epoch: 048/050 | Batch 0100/0175 | Loss: 0.0553
# Epoch: 048/050 | Train: 99.95% | Validation: 77.24%
# Time elapsed: 29.78 min
# Epoch: 049/050 | Batch 0000/0175 | Loss: 0.0648
# Epoch: 049/050 | Batch 0100/0175 | Loss: 0.0619
# Epoch: 049/050 | Train: 99.96% | Validation: 76.84%
# Time elapsed: 30.39 min
# Epoch    49: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 050/050 | Batch 0000/0175 | Loss: 0.0574
# Epoch: 050/050 | Batch 0100/0175 | Loss: 0.0426
# Epoch: 050/050 | Train: 99.95% | Validation: 77.40%
# Time elapsed: 31.00 min
# Total Training Time: 31.00 min
# Test accuracy 74.95%

# %%
model.cpu()
unnormalizer = UnNormalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
class_dict = {0: 'airplane',
              1: 'automobile',
              2: 'bird',
              3: 'cat',
              4: 'deer',
              5: 'dog',
              6: 'frog',
              7: 'horse',
              8: 'ship',
              9: 'truck'}

show_examples(model=model, data_loader=test_loader, unnormalizer=unnormalizer, class_dict=class_dict)

# %%
mat = compute_confusion_matrix(model=model, data_loader=test_loader, device=torch.device('cpu'))
plot_confusion_matrix(mat, class_names=class_dict.values())
plt.show()
