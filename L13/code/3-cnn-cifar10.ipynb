# %% [markdown]
# STAT 453: Deep Learning (Spring 2021)
# Instructor: Sebastian Raschka (sraschka@wisc.edu)
#
# Course website: http://pages.stat.wisc.edu/~sraschka/teaching/stat453-ss2021/
# GitHub repository: https://github.com/rasbt/stat453-deep-learning-ss21
#
# ---

# %%
# %load_ext watermark
# %watermark -a 'Sebastian Raschka' -v -p torch
# Out:
# Author: Sebastian Raschka
#
# Python implementation: CPython
# Python version       : 3.8.8
# IPython version      : 7.21.0
#
# torch: 1.8.0

# %% [markdown]
# # AlexNet on Cifar-10

# %% [markdown]
# ## Imports

# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# %%
# From local helper files
from helper_evaluation import set_all_seeds, set_deterministic
from helper_train import train_model
from helper_plotting import plot_training_loss, plot_accuracy, show_examples
from helper_dataset import get_dataloaders_cifar10, UnNormalize

# %% [markdown]
# ## Settings and Dataset

# %%
##########################
### SETTINGS
##########################

RANDOM_SEED = 123
BATCH_SIZE = 256
NUM_EPOCHS = 50
DEVICE = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')

# %%
set_all_seeds(RANDOM_SEED)
#set_deterministic()

# %%
##########################
### MNIST DATASET
##########################

train_transforms = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transforms = torchvision.transforms.Compose([            
    torchvision.transforms.ToTensor(),                
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])


train_loader, valid_loader, test_loader = get_dataloaders_cifar10(
    batch_size=BATCH_SIZE,
    validation_fraction=0.1,
    train_transforms=train_transforms,
    test_transforms=test_transforms,
    num_workers=2)

# Checking the dataset
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    print('Class labels of 10 examples:', labels[:10])
    break
# Out:
# Files already downloaded and verified
# Image batch dimensions: torch.Size([256, 3, 32, 32])
# Image label dimensions: torch.Size([256])
# Class labels of 10 examples: tensor([4, 7, 4, 6, 2, 6, 9, 7, 3, 0])

# %% [markdown]
# ## Model

# %%
class ConvNet(torch.nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.num_classes = num_classes
        self.layers = torch.nn.Sequential(
                torch.nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1),
                torch.nn.BatchNorm2d(32),
                torch.nn.LeakyReLU(0.1, inplace=True),
                #
                torch.nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
                torch.nn.BatchNorm2d(64),
                torch.nn.LeakyReLU(0.1, inplace=True),
                #
                torch.nn.Conv2d(64, 64, kernel_size=3, stride=2, padding=1),
                torch.nn.BatchNorm2d(64),
                torch.nn.LeakyReLU(0.1, inplace=True),
                #
                torch.nn.Flatten(),
                torch.nn.Linear(4096, 128),
                torch.nn.BatchNorm1d(128),
                torch.nn.LeakyReLU(0.1, inplace=True),
                torch.nn.Dropout(0.5),
                #
                torch.nn.Linear(128, num_classes),
                )

    def forward(self, x):
        logits = self.layers(x)
        #probas = torch.softmax(logits, dim=1)
        return logits

# %%
model = ConvNet(num_classes=10)

model = model.to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), momentum=0.9, lr=0.1)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,
                                                       factor=0.1,
                                                       mode='max',
                                                       verbose=True)

minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=NUM_EPOCHS,
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=DEVICE,
    scheduler=scheduler,
    scheduler_on='valid_acc',
    logging_interval=100)

plot_training_loss(minibatch_loss_list=minibatch_loss_list,
                   num_epochs=NUM_EPOCHS,
                   iter_per_epoch=len(train_loader),
                   results_dir=None,
                   averaging_iterations=20)
plt.show()

plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([60, 100])
plt.show()
# Out:
# Epoch: 001/050 | Batch 0000/0175 | Loss: 2.4832
# Epoch: 001/050 | Batch 0100/0175 | Loss: 1.4447
# Epoch: 001/050 | Train: 52.59% | Validation: 52.26%
# Time elapsed: 0.63 min
# Epoch: 002/050 | Batch 0000/0175 | Loss: 1.2109
# Epoch: 002/050 | Batch 0100/0175 | Loss: 1.0998
# Epoch: 002/050 | Train: 66.14% | Validation: 63.28%
# Time elapsed: 1.28 min
# Epoch: 003/050 | Batch 0000/0175 | Loss: 1.0204
# Epoch: 003/050 | Batch 0100/0175 | Loss: 0.9906
# Epoch: 003/050 | Train: 70.68% | Validation: 67.04%
# Time elapsed: 1.98 min
# Epoch: 004/050 | Batch 0000/0175 | Loss: 0.8259
# Epoch: 004/050 | Batch 0100/0175 | Loss: 0.9525
# Epoch: 004/050 | Train: 73.65% | Validation: 70.14%
# Time elapsed: 2.66 min
# Epoch: 005/050 | Batch 0000/0175 | Loss: 0.7508
# Epoch: 005/050 | Batch 0100/0175 | Loss: 0.8660
# Epoch: 005/050 | Train: 78.28% | Validation: 72.88%
# Time elapsed: 3.34 min
# Epoch: 006/050 | Batch 0000/0175 | Loss: 0.7427
# Epoch: 006/050 | Batch 0100/0175 | Loss: 0.6461
# Epoch: 006/050 | Train: 80.48% | Validation: 73.24%
# Time elapsed: 4.02 min
# Epoch: 007/050 | Batch 0000/0175 | Loss: 0.6734
# Epoch: 007/050 | Batch 0100/0175 | Loss: 0.7559
# Epoch: 007/050 | Train: 83.11% | Validation: 74.98%
# Time elapsed: 4.72 min
# Epoch: 008/050 | Batch 0000/0175 | Loss: 0.6367
# Epoch: 008/050 | Batch 0100/0175 | Loss: 0.7325
# Epoch: 008/050 | Train: 81.49% | Validation: 72.44%
# Time elapsed: 5.40 min
# Epoch: 009/050 | Batch 0000/0175 | Loss: 0.5020
# Epoch: 009/050 | Batch 0100/0175 | Loss: 0.6963
# Epoch: 009/050 | Train: 86.29% | Validation: 74.36%
# Time elapsed: 6.09 min
# Epoch: 010/050 | Batch 0000/0175 | Loss: 0.5027
# Epoch: 010/050 | Batch 0100/0175 | Loss: 0.6682
# Epoch: 010/050 | Train: 86.54% | Validation: 73.10%
# Time elapsed: 6.77 min
# Epoch: 011/050 | Batch 0000/0175 | Loss: 0.6043
# Epoch: 011/050 | Batch 0100/0175 | Loss: 0.5820
# Epoch: 011/050 | Train: 89.51% | Validation: 75.22%
# Time elapsed: 7.46 min
# Epoch: 012/050 | Batch 0000/0175 | Loss: 0.4398
# Epoch: 012/050 | Batch 0100/0175 | Loss: 0.5132
# Epoch: 012/050 | Train: 90.93% | Validation: 75.02%
# Time elapsed: 8.15 min
# Epoch: 013/050 | Batch 0000/0175 | Loss: 0.4705
# Epoch: 013/050 | Batch 0100/0175 | Loss: 0.3489
# Epoch: 013/050 | Train: 91.45% | Validation: 74.36%
# Time elapsed: 8.83 min
# Epoch: 014/050 | Batch 0000/0175 | Loss: 0.3744
# Epoch: 014/050 | Batch 0100/0175 | Loss: 0.3855
# Epoch: 014/050 | Train: 91.97% | Validation: 74.06%
# Time elapsed: 9.51 min
# Epoch: 015/050 | Batch 0000/0175 | Loss: 0.2688
# Epoch: 015/050 | Batch 0100/0175 | Loss: 0.4041
# Epoch: 015/050 | Train: 94.25% | Validation: 75.12%
# Time elapsed: 10.21 min
# Epoch: 016/050 | Batch 0000/0175 | Loss: 0.2599
# Epoch: 016/050 | Batch 0100/0175 | Loss: 0.3423
# Epoch: 016/050 | Train: 93.24% | Validation: 74.42%
# Time elapsed: 10.89 min
# Epoch: 017/050 | Batch 0000/0175 | Loss: 0.3051
# Epoch: 017/050 | Batch 0100/0175 | Loss: 0.4691
# Epoch: 017/050 | Train: 94.20% | Validation: 74.58%
# Time elapsed: 11.58 min
# Epoch: 018/050 | Batch 0000/0175 | Loss: 0.3330
# Epoch: 018/050 | Batch 0100/0175 | Loss: 0.2846
# Epoch: 018/050 | Train: 94.68% | Validation: 74.46%
# Time elapsed: 12.25 min
# Epoch: 019/050 | Batch 0000/0175 | Loss: 0.3081
# Epoch: 019/050 | Batch 0100/0175 | Loss: 0.2977
# Epoch: 019/050 | Train: 96.18% | Validation: 75.36%
# Time elapsed: 12.94 min
# Epoch: 020/050 | Batch 0000/0175 | Loss: 0.2494
# Epoch: 020/050 | Batch 0100/0175 | Loss: 0.2799
# Epoch: 020/050 | Train: 96.04% | Validation: 73.74%
# Time elapsed: 13.64 min
# Epoch: 021/050 | Batch 0000/0175 | Loss: 0.2767
# Epoch: 021/050 | Batch 0100/0175 | Loss: 0.2274
# Epoch: 021/050 | Train: 97.15% | Validation: 75.36%
# Time elapsed: 14.32 min
# Epoch: 022/050 | Batch 0000/0175 | Loss: 0.1985
# Epoch: 022/050 | Batch 0100/0175 | Loss: 0.1906
# Epoch: 022/050 | Train: 97.06% | Validation: 74.44%
# Time elapsed: 15.00 min
# Epoch: 023/050 | Batch 0000/0175 | Loss: 0.2091
# Epoch: 023/050 | Batch 0100/0175 | Loss: 0.2406
# Epoch: 023/050 | Train: 97.75% | Validation: 74.40%
# Time elapsed: 15.70 min
# Epoch: 038/050 | Batch 0000/0175 | Loss: 0.0574
# Epoch: 038/050 | Batch 0100/0175 | Loss: 0.1016
# Epoch: 038/050 | Train: 99.94% | Validation: 75.06%
# Time elapsed: 25.99 min
# Epoch: 039/050 | Batch 0000/0175 | Loss: 0.0875
# Epoch: 039/050 | Batch 0100/0175 | Loss: 0.0588
# Epoch: 039/050 | Train: 99.95% | Validation: 75.32%
# Time elapsed: 26.67 min
# Epoch: 040/050 | Batch 0000/0175 | Loss: 0.0858
# Epoch: 040/050 | Batch 0100/0175 | Loss: 0.0565
# Epoch: 040/050 | Train: 99.95% | Validation: 75.04%
# Time elapsed: 27.36 min
# Epoch: 041/050 | Batch 0000/0175 | Loss: 0.0943
# Epoch: 041/050 | Batch 0100/0175 | Loss: 0.0610
# Epoch: 041/050 | Train: 99.96% | Validation: 75.38%
# Time elapsed: 28.05 min
# Epoch: 042/050 | Batch 0000/0175 | Loss: 0.0491
# Epoch: 042/050 | Batch 0100/0175 | Loss: 0.0651
# Epoch: 042/050 | Train: 99.97% | Validation: 75.06%
# Time elapsed: 28.74 min
# Epoch: 043/050 | Batch 0000/0175 | Loss: 0.0493
# Epoch: 043/050 | Batch 0100/0175 | Loss: 0.0342
# Epoch: 043/050 | Train: 99.97% | Validation: 75.00%
# Time elapsed: 29.43 min
# Epoch: 044/050 | Batch 0000/0175 | Loss: 0.0739
# Epoch: 044/050 | Batch 0100/0175 | Loss: 0.0527
# Epoch: 044/050 | Train: 99.97% | Validation: 75.22%
# Time elapsed: 30.12 min
# Epoch: 045/050 | Batch 0000/0175 | Loss: 0.0720
# Epoch: 045/050 | Batch 0100/0175 | Loss: 0.0472
# Epoch: 045/050 | Train: 99.97% | Validation: 75.14%
# Time elapsed: 30.82 min
# Epoch: 046/050 | Batch 0000/0175 | Loss: 0.0454
# Epoch: 046/050 | Batch 0100/0175 | Loss: 0.0472
# Epoch: 046/050 | Train: 99.96% | Validation: 75.44%
# Time elapsed: 31.50 min
# Epoch: 047/050 | Batch 0000/0175 | Loss: 0.0496
# Epoch: 047/050 | Batch 0100/0175 | Loss: 0.0457
# Epoch: 047/050 | Train: 99.97% | Validation: 75.30%
# Time elapsed: 32.19 min
# Epoch: 048/050 | Batch 0000/0175 | Loss: 0.1051
# Epoch: 048/050 | Batch 0100/0175 | Loss: 0.0456
# Epoch: 048/050 | Train: 99.98% | Validation: 75.30%
# Time elapsed: 32.88 min
# Epoch: 049/050 | Batch 0000/0175 | Loss: 0.0583
# Epoch: 049/050 | Batch 0100/0175 | Loss: 0.0455
# Epoch: 049/050 | Train: 99.98% | Validation: 75.40%
# Time elapsed: 33.57 min
# Epoch: 050/050 | Batch 0000/0175 | Loss: 0.0397
# Epoch: 050/050 | Batch 0100/0175 | Loss: 0.0466
# Epoch: 050/050 | Train: 99.98% | Validation: 75.58%
# Time elapsed: 34.26 min
# Total Training Time: 34.26 min
# Test accuracy 74.71%

# %%
model.cpu()
unnormalizer = UnNormalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
class_dict = {0: 'airplane',
              1: 'automobile',
              2: 'bird',
              3: 'cat',
              4: 'deer',
              5: 'dog',
              6: 'frog',
              7: 'horse',
              8: 'ship',
              9: 'truck'}

show_examples(model=model, data_loader=test_loader, unnormalizer=unnormalizer, class_dict=class_dict)
