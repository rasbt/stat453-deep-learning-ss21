# %% [markdown]
# STAT 453: Deep Learning (Spring 2021)
# Instructor: Sebastian Raschka (sraschka@wisc.edu)
#
# Course website: http://pages.stat.wisc.edu/~sraschka/teaching/stat453-ss2021/
# GitHub repository: https://github.com/rasbt/stat453-deep-learning-ss21
#
# ---

# %% [markdown]
# # Deep Convolutional GAN Trained on CelebA

# %%
# %load_ext watermark
# %watermark -a 'Sebastian Raschka' -v -p torch
# Out:
# Author: Sebastian Raschka
#
# Python implementation: CPython
# Python version       : 3.8.8
# IPython version      : 7.21.0
#
# torch: 1.8.1+cu111

# %% [markdown]
# ## Imports

# %%
import numpy as np
import torch
import torchvision
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# #### Import utility functions

# %%
import sys
sys.path.append('../')

from helper_data import get_dataloaders_celeba
from helper_train import train_wgan_v1
from helper_utils import set_deterministic, set_all_seeds
from helper_plotting import plot_multiple_training_losses
from helper_plotting import plot_generated_images

# %%
##########################
### SETTINGS
##########################

# Device
CUDA_DEVICE_NUM = 2
DEVICE = torch.device(f'cuda:{CUDA_DEVICE_NUM}' if torch.cuda.is_available() else 'cpu')
print('Device:', DEVICE)

# Hyperparameters
RANDOM_SEED = 42
GENERATOR_LEARNING_RATE = 0.0002
DISCRIMINATOR_LEARNING_RATE = 0.0002

NUM_EPOCHS = 20
BATCH_SIZE = 128

IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS = 64, 64, 3
# Out:
# Device: cuda:2

# %%
set_deterministic
set_all_seeds(RANDOM_SEED)

# %% [markdown]
# ## Dataset

# %%
##########################
### Dataset
##########################


custom_transforms = torchvision.transforms.Compose([
    torchvision.transforms.CenterCrop((160, 160)),
    torchvision.transforms.Resize([IMAGE_HEIGHT, IMAGE_WIDTH]),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])


train_loader, valid_loader, test_loader = get_dataloaders_celeba(
    batch_size=BATCH_SIZE,
    train_transforms=custom_transforms,
    test_transforms=custom_transforms,
    download=False,
    num_workers=4)

# %%
# Checking the dataset
print('Training Set:\n')
for images, labels in train_loader:  
    print('Image batch dimensions:', images.size())
    print('Image label dimensions:', labels.size())
    #print(labels[:10])
    break
    
# Checking the dataset
print('\nValidation Set:')
for images, labels in valid_loader:  
    print('Image batch dimensions:', images.size())
    print('Image label dimensions:', labels.size())
    #print(labels[:10])
    break

# Checking the dataset
print('\nTesting Set:')
for images, labels in test_loader:  
    print('Image batch dimensions:', images.size())
    print('Image label dimensions:', labels.size())
    #print(labels[:10])
    break
# Out:
# Training Set:
#
# Image batch dimensions: torch.Size([128, 3, 64, 64])
# Image label dimensions: torch.Size([128, 40])
#
# Validation Set:
# Image batch dimensions: torch.Size([128, 3, 64, 64])
# Image label dimensions: torch.Size([128, 40])
#
# Testing Set:
# Image batch dimensions: torch.Size([128, 3, 64, 64])
# Image label dimensions: torch.Size([128, 40])

# %%
plt.figure(figsize=(8, 8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(torchvision.utils.make_grid(images[:64], 
                                         padding=2, normalize=True),
                        (1, 2, 0)))

# %% [markdown]
# ## Model

# %%
##########################
### MODEL
##########################

class DCGAN(torch.nn.Module):

    def __init__(self, latent_dim=100, 
                 num_feat_maps_gen=64, num_feat_maps_dis=64,
                 color_channels=3):
        super().__init__()
        
        
        self.generator = nn.Sequential(
            nn.ConvTranspose2d(latent_dim, num_feat_maps_gen*8, 
                               kernel_size=4, stride=1, padding=0,
                               bias=False),
            nn.BatchNorm2d(num_feat_maps_gen*8),
            nn.LeakyReLU(inplace=True),
            #
            # size if latent_dim=100: num_feat_maps_gen*8 x 4 x 4
            #
            nn.ConvTranspose2d(num_feat_maps_gen*8, num_feat_maps_gen*4, 
                               kernel_size=4, stride=2, padding=1,
                               bias=False),
            nn.BatchNorm2d(num_feat_maps_gen*4),
            nn.LeakyReLU(inplace=True),
            #
            # size if latent_dim=100: num_feat_maps_gen*4 x 8 x 8
            #
            nn.ConvTranspose2d(num_feat_maps_gen*4, num_feat_maps_gen*2, 
                               kernel_size=4, stride=2, padding=1,
                               bias=False),
            nn.BatchNorm2d(num_feat_maps_gen*2),
            nn.LeakyReLU(inplace=True),
            #
            # size if latent_dim=100: num_feat_maps_gen*2 x 16 x 16
            #
            nn.ConvTranspose2d(num_feat_maps_gen*2, num_feat_maps_gen, 
                               kernel_size=4, stride=2, padding=1,
                               bias=False),
            nn.BatchNorm2d(num_feat_maps_gen),
            nn.LeakyReLU(inplace=True),
            #
            # size if latent_dim=100: num_feat_maps_gen x 32 x 32
            #
            nn.ConvTranspose2d(num_feat_maps_gen, color_channels, 
                               kernel_size=4, stride=2, padding=1,
                               bias=False),
            #
            # size: color_channels x 64 x 64
            #  
            nn.Tanh()
        )
        
        self.discriminator = nn.Sequential(
            #
            # input size color_channels x image_height x image_width
            #
            nn.Conv2d(color_channels, num_feat_maps_dis,
                      kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(inplace=True),
            #
            # size: num_feat_maps_dis x 32 x 32
            #              
            nn.Conv2d(num_feat_maps_dis, num_feat_maps_dis*2,
                      kernel_size=4, stride=2, padding=1,
                      bias=False),        
            nn.BatchNorm2d(num_feat_maps_dis*2),
            nn.LeakyReLU(inplace=True),
            #
            # size: num_feat_maps_dis*2 x 16 x 16
            #   
            nn.Conv2d(num_feat_maps_dis*2, num_feat_maps_dis*4,
                      kernel_size=4, stride=2, padding=1,
                      bias=False),        
            nn.BatchNorm2d(num_feat_maps_dis*4),
            nn.LeakyReLU(inplace=True),
            #
            # size: num_feat_maps_dis*4 x 8 x 8
            #   
            nn.Conv2d(num_feat_maps_dis*4, num_feat_maps_dis*8,
                      kernel_size=4, stride=2, padding=1,
                      bias=False),        
            nn.BatchNorm2d(num_feat_maps_dis*8),
            nn.LeakyReLU(inplace=True),
            #
            # size: num_feat_maps_dis*8 x 4 x 4
            #   
            nn.Conv2d(num_feat_maps_dis*8, 1,
                      kernel_size=4, stride=1, padding=0),
            
            # size: 1 x 1 x 1
            nn.Flatten(),
        )

            
    def generator_forward(self, z):
        img = self.generator(z)
        return img
    
    def discriminator_forward(self, img):
        logits = model.discriminator(img)
        return logits

# %%
set_all_seeds(RANDOM_SEED)

model = DCGAN()
model.to(DEVICE)


optim_gen = torch.optim.Adam(model.generator.parameters(),
                             betas=(0.5, 0.999),
                             lr=GENERATOR_LEARNING_RATE)

optim_discr = torch.optim.Adam(model.discriminator.parameters(),
                               betas=(0.5, 0.999),
                               lr=DISCRIMINATOR_LEARNING_RATE)

# %% [markdown]
# ## Training

# %%
log_dict = train_wgan_v1(num_epochs=NUM_EPOCHS, model=model, 
                         optimizer_gen=optim_gen,
                         optimizer_discr=optim_discr,
                         latent_dim=100,
                         device=DEVICE,
                         train_loader=train_loader,
                         logging_interval=100,
                         save_model='wgan_mnist_01.pt')
# Out:
# Epoch: 001/020 | Batch 000/1272 | Gen/Dis Loss: 0.0036/0.0658
# Epoch: 001/020 | Batch 100/1272 | Gen/Dis Loss: 0.2725/-0.1197
# Epoch: 001/020 | Batch 200/1272 | Gen/Dis Loss: 0.1733/-0.0863
# Epoch: 001/020 | Batch 300/1272 | Gen/Dis Loss: 0.1974/-0.1460
# Epoch: 001/020 | Batch 400/1272 | Gen/Dis Loss: 0.3618/-0.2907
# Epoch: 001/020 | Batch 500/1272 | Gen/Dis Loss: 0.3985/-0.3634
# Epoch: 001/020 | Batch 600/1272 | Gen/Dis Loss: 0.4514/-0.4436
# Epoch: 001/020 | Batch 700/1272 | Gen/Dis Loss: 0.4374/-0.1948
# Epoch: 001/020 | Batch 800/1272 | Gen/Dis Loss: 0.4439/-0.2860
# Epoch: 001/020 | Batch 900/1272 | Gen/Dis Loss: 0.2728/-0.2689
# Epoch: 001/020 | Batch 1000/1272 | Gen/Dis Loss: 0.2251/-0.2892
# Epoch: 001/020 | Batch 1100/1272 | Gen/Dis Loss: 0.5913/-0.3445
# Epoch: 001/020 | Batch 1200/1272 | Gen/Dis Loss: 0.5290/-0.3832
# Time elapsed: 2.18 min
# Epoch: 002/020 | Batch 000/1272 | Gen/Dis Loss: 0.5071/-0.3934
# Epoch: 002/020 | Batch 100/1272 | Gen/Dis Loss: 0.1908/-0.2766
# Epoch: 002/020 | Batch 200/1272 | Gen/Dis Loss: 0.3331/-0.2814
# Epoch: 002/020 | Batch 300/1272 | Gen/Dis Loss: 0.2215/-0.3227
# Epoch: 002/020 | Batch 400/1272 | Gen/Dis Loss: 0.3200/-0.2586
# Epoch: 002/020 | Batch 500/1272 | Gen/Dis Loss: 0.3676/-0.2941
# Epoch: 002/020 | Batch 600/1272 | Gen/Dis Loss: 0.2475/-0.3167
# Epoch: 002/020 | Batch 700/1272 | Gen/Dis Loss: 0.3233/-0.2564
# Epoch: 002/020 | Batch 800/1272 | Gen/Dis Loss: 0.4895/-0.2814
# Epoch: 002/020 | Batch 900/1272 | Gen/Dis Loss: 0.3894/-0.3359
# Epoch: 002/020 | Batch 1000/1272 | Gen/Dis Loss: 0.1987/-0.2086
# Epoch: 002/020 | Batch 1100/1272 | Gen/Dis Loss: 0.4249/-0.2243
# Epoch: 002/020 | Batch 1200/1272 | Gen/Dis Loss: 0.5210/-0.3159
# Time elapsed: 4.40 min
# Epoch: 003/020 | Batch 000/1272 | Gen/Dis Loss: 0.0768/-0.2075
# Epoch: 003/020 | Batch 100/1272 | Gen/Dis Loss: 0.1328/-0.2634
# Epoch: 003/020 | Batch 200/1272 | Gen/Dis Loss: 0.3881/-0.3300
# Epoch: 003/020 | Batch 300/1272 | Gen/Dis Loss: 0.1972/-0.2287
# Epoch: 003/020 | Batch 400/1272 | Gen/Dis Loss: 0.2369/-0.1834
# Epoch: 003/020 | Batch 500/1272 | Gen/Dis Loss: 0.2462/-0.1904
# Epoch: 003/020 | Batch 600/1272 | Gen/Dis Loss: 0.2082/-0.2283
# Epoch: 003/020 | Batch 700/1272 | Gen/Dis Loss: 0.3200/-0.2097
# Epoch: 003/020 | Batch 800/1272 | Gen/Dis Loss: 0.2711/-0.1936
# Epoch: 003/020 | Batch 900/1272 | Gen/Dis Loss: 0.2355/-0.2966
# Epoch: 003/020 | Batch 1000/1272 | Gen/Dis Loss: 0.3404/-0.2367
# Epoch: 003/020 | Batch 1100/1272 | Gen/Dis Loss: 0.2786/-0.2024
# Epoch: 003/020 | Batch 1200/1272 | Gen/Dis Loss: 0.1331/-0.2390
# Time elapsed: 6.61 min
# Epoch: 004/020 | Batch 000/1272 | Gen/Dis Loss: 0.1205/-0.2025
# Epoch: 004/020 | Batch 100/1272 | Gen/Dis Loss: 0.3050/-0.2475
# Epoch: 004/020 | Batch 200/1272 | Gen/Dis Loss: 0.3816/-0.2542
# Epoch: 004/020 | Batch 300/1272 | Gen/Dis Loss: 0.1542/-0.1993
# Epoch: 004/020 | Batch 400/1272 | Gen/Dis Loss: 0.3202/-0.2255
# Epoch: 004/020 | Batch 500/1272 | Gen/Dis Loss: 0.2926/-0.1462
# Epoch: 004/020 | Batch 600/1272 | Gen/Dis Loss: 0.1572/-0.2503
# Epoch: 004/020 | Batch 700/1272 | Gen/Dis Loss: 0.2961/-0.2276
# Epoch: 004/020 | Batch 800/1272 | Gen/Dis Loss: 0.3190/-0.1494
# Epoch: 004/020 | Batch 900/1272 | Gen/Dis Loss: 0.1763/-0.2071
# Epoch: 004/020 | Batch 1000/1272 | Gen/Dis Loss: 0.3662/-0.1786
# Epoch: 004/020 | Batch 1100/1272 | Gen/Dis Loss: 0.1666/-0.1885
# Epoch: 004/020 | Batch 1200/1272 | Gen/Dis Loss: 0.3564/-0.2259
# Time elapsed: 8.82 min
# Epoch: 005/020 | Batch 000/1272 | Gen/Dis Loss: 0.3021/-0.1586
# Epoch: 005/020 | Batch 100/1272 | Gen/Dis Loss: 0.0885/-0.1938
# Epoch: 005/020 | Batch 200/1272 | Gen/Dis Loss: 0.2981/-0.1800
# Epoch: 005/020 | Batch 300/1272 | Gen/Dis Loss: 0.4148/-0.2271
# Epoch: 005/020 | Batch 400/1272 | Gen/Dis Loss: 0.4576/-0.1496
# Epoch: 005/020 | Batch 500/1272 | Gen/Dis Loss: 0.1755/-0.1632
# Epoch: 005/020 | Batch 600/1272 | Gen/Dis Loss: 0.3377/-0.2086
# Epoch: 005/020 | Batch 700/1272 | Gen/Dis Loss: 0.1461/-0.1521
# Epoch: 005/020 | Batch 800/1272 | Gen/Dis Loss: 0.2259/-0.1605
# Epoch: 005/020 | Batch 900/1272 | Gen/Dis Loss: 0.0866/-0.2058
# Epoch: 005/020 | Batch 1000/1272 | Gen/Dis Loss: 0.1344/-0.1756
# Epoch: 005/020 | Batch 1100/1272 | Gen/Dis Loss: 0.4434/-0.1258
# Epoch: 005/020 | Batch 1200/1272 | Gen/Dis Loss: 0.1790/-0.1836
# Time elapsed: 11.03 min
# Epoch: 006/020 | Batch 000/1272 | Gen/Dis Loss: 0.0907/-0.1673
# Epoch: 006/020 | Batch 100/1272 | Gen/Dis Loss: 0.3543/-0.1776
# Epoch: 006/020 | Batch 200/1272 | Gen/Dis Loss: 0.2113/-0.1548
# Epoch: 006/020 | Batch 300/1272 | Gen/Dis Loss: 0.2212/-0.2048
# Epoch: 006/020 | Batch 400/1272 | Gen/Dis Loss: 0.0445/-0.1540
# Epoch: 006/020 | Batch 500/1272 | Gen/Dis Loss: 0.0598/-0.1286
# Epoch: 006/020 | Batch 600/1272 | Gen/Dis Loss: 0.2528/-0.1876
# Epoch: 006/020 | Batch 700/1272 | Gen/Dis Loss: 0.4122/-0.1610
# Epoch: 006/020 | Batch 800/1272 | Gen/Dis Loss: 0.1994/-0.1623
# Epoch: 006/020 | Batch 900/1272 | Gen/Dis Loss: -0.1650/-0.1759
# Epoch: 006/020 | Batch 1000/1272 | Gen/Dis Loss: 0.2731/-0.1089
# Epoch: 006/020 | Batch 1100/1272 | Gen/Dis Loss: -0.0473/-0.1569
# Epoch: 006/020 | Batch 1200/1272 | Gen/Dis Loss: 0.2523/-0.1884
# Time elapsed: 13.25 min
# Epoch: 007/020 | Batch 000/1272 | Gen/Dis Loss: 0.3495/-0.1628
# Epoch: 007/020 | Batch 100/1272 | Gen/Dis Loss: 0.1799/-0.1255
# Epoch: 007/020 | Batch 200/1272 | Gen/Dis Loss: 0.1470/-0.1208
# Epoch: 007/020 | Batch 300/1272 | Gen/Dis Loss: 0.3226/-0.1738
# Epoch: 007/020 | Batch 400/1272 | Gen/Dis Loss: 0.3003/-0.1228
# Epoch: 007/020 | Batch 500/1272 | Gen/Dis Loss: 0.3132/-0.1111
# Epoch: 007/020 | Batch 600/1272 | Gen/Dis Loss: 0.2817/-0.1669
# Epoch: 007/020 | Batch 700/1272 | Gen/Dis Loss: 0.3543/-0.0956
# Epoch: 007/020 | Batch 800/1272 | Gen/Dis Loss: 0.1973/-0.1138
# Epoch: 007/020 | Batch 900/1272 | Gen/Dis Loss: 0.1972/-0.1975
# Epoch: 007/020 | Batch 1000/1272 | Gen/Dis Loss: 0.2529/-0.0720
# Epoch: 007/020 | Batch 1100/1272 | Gen/Dis Loss: 0.2051/-0.1283
# Epoch: 007/020 | Batch 1200/1272 | Gen/Dis Loss: 0.0971/-0.1027
# Time elapsed: 15.46 min
# Epoch: 008/020 | Batch 000/1272 | Gen/Dis Loss: 0.3646/-0.1925
# Epoch: 008/020 | Batch 100/1272 | Gen/Dis Loss: 0.0044/-0.1276
# Epoch: 008/020 | Batch 200/1272 | Gen/Dis Loss: 0.2118/-0.1427
# Epoch: 008/020 | Batch 300/1272 | Gen/Dis Loss: 0.3910/-0.1897
# Epoch: 008/020 | Batch 400/1272 | Gen/Dis Loss: 0.2702/-0.1140
# Epoch: 008/020 | Batch 500/1272 | Gen/Dis Loss: 0.0948/-0.1388
# Epoch: 008/020 | Batch 600/1272 | Gen/Dis Loss: 0.1778/-0.1442
# Epoch: 008/020 | Batch 700/1272 | Gen/Dis Loss: 0.2733/-0.0883
# Epoch: 008/020 | Batch 800/1272 | Gen/Dis Loss: 0.2411/-0.0968
# Epoch: 008/020 | Batch 900/1272 | Gen/Dis Loss: 0.3709/-0.1488
# Epoch: 008/020 | Batch 1000/1272 | Gen/Dis Loss: 0.2204/-0.1066
# Epoch: 008/020 | Batch 1100/1272 | Gen/Dis Loss: 0.1776/-0.1494
# Epoch: 008/020 | Batch 1200/1272 | Gen/Dis Loss: 0.2893/-0.1492
# Time elapsed: 17.67 min
# Epoch: 009/020 | Batch 000/1272 | Gen/Dis Loss: 0.4273/-0.1542
# Epoch: 009/020 | Batch 100/1272 | Gen/Dis Loss: 0.1602/-0.0849
# Epoch: 009/020 | Batch 200/1272 | Gen/Dis Loss: 0.2268/-0.1169
# Epoch: 009/020 | Batch 300/1272 | Gen/Dis Loss: 0.2039/-0.1407
# Epoch: 009/020 | Batch 400/1272 | Gen/Dis Loss: 0.3501/-0.1284
# Epoch: 009/020 | Batch 500/1272 | Gen/Dis Loss: 0.2506/-0.1016
# Epoch: 009/020 | Batch 600/1272 | Gen/Dis Loss: -0.0551/-0.1287
# Epoch: 009/020 | Batch 700/1272 | Gen/Dis Loss: 0.2996/-0.0821
# Epoch: 009/020 | Batch 800/1272 | Gen/Dis Loss: 0.1817/-0.0715
# Epoch: 009/020 | Batch 900/1272 | Gen/Dis Loss: 0.3411/-0.1011
# Epoch: 009/020 | Batch 1000/1272 | Gen/Dis Loss: 0.1729/-0.0670
# Epoch: 009/020 | Batch 1100/1272 | Gen/Dis Loss: 0.2659/-0.0963
# Epoch: 009/020 | Batch 1200/1272 | Gen/Dis Loss: 0.1136/-0.1136
# Time elapsed: 19.88 min
# Epoch: 010/020 | Batch 000/1272 | Gen/Dis Loss: 0.0942/-0.1449
# Epoch: 010/020 | Batch 100/1272 | Gen/Dis Loss: -0.0166/-0.0932
# Epoch: 010/020 | Batch 200/1272 | Gen/Dis Loss: 0.0752/-0.1008
# Epoch: 010/020 | Batch 300/1272 | Gen/Dis Loss: 0.1642/-0.1263
# Epoch: 010/020 | Batch 400/1272 | Gen/Dis Loss: 0.1874/-0.0758
# Epoch: 010/020 | Batch 500/1272 | Gen/Dis Loss: 0.0376/-0.1512
# Epoch: 010/020 | Batch 600/1272 | Gen/Dis Loss: 0.3421/-0.1105
# Epoch: 010/020 | Batch 700/1272 | Gen/Dis Loss: 0.2027/-0.0842
# Epoch: 010/020 | Batch 800/1272 | Gen/Dis Loss: -0.0260/-0.0935
# Epoch: 010/020 | Batch 900/1272 | Gen/Dis Loss: 0.1513/-0.1008
# Epoch: 010/020 | Batch 1000/1272 | Gen/Dis Loss: 0.2469/-0.0779
# Epoch: 010/020 | Batch 1100/1272 | Gen/Dis Loss: 0.1374/-0.0834
# Epoch: 010/020 | Batch 1200/1272 | Gen/Dis Loss: 0.1036/-0.1813
# Time elapsed: 22.09 min
# Epoch: 011/020 | Batch 000/1272 | Gen/Dis Loss: 0.1710/-0.0956
# Epoch: 011/020 | Batch 100/1272 | Gen/Dis Loss: 0.1204/-0.0695
# Epoch: 011/020 | Batch 200/1272 | Gen/Dis Loss: 0.3216/-0.1354
# Epoch: 011/020 | Batch 300/1272 | Gen/Dis Loss: 0.0862/-0.1194
# Epoch: 011/020 | Batch 400/1272 | Gen/Dis Loss: 0.2055/-0.0540
# Epoch: 011/020 | Batch 500/1272 | Gen/Dis Loss: 0.2203/-0.0623
# Epoch: 011/020 | Batch 600/1272 | Gen/Dis Loss: -0.1492/-0.0984
# Epoch: 011/020 | Batch 700/1272 | Gen/Dis Loss: 0.2964/-0.0428
# Epoch: 011/020 | Batch 800/1272 | Gen/Dis Loss: 0.2002/-0.0816
# Epoch: 011/020 | Batch 900/1272 | Gen/Dis Loss: 0.0544/-0.0423
# Epoch: 011/020 | Batch 1000/1272 | Gen/Dis Loss: 0.0730/-0.0606
# Epoch: 011/020 | Batch 1100/1272 | Gen/Dis Loss: 0.0643/-0.0973
# Epoch: 011/020 | Batch 1200/1272 | Gen/Dis Loss: 0.1690/-0.0314
# Time elapsed: 24.30 min
# Epoch: 012/020 | Batch 000/1272 | Gen/Dis Loss: 0.2395/-0.0184
# Epoch: 012/020 | Batch 100/1272 | Gen/Dis Loss: 0.3775/-0.0319
# Epoch: 012/020 | Batch 200/1272 | Gen/Dis Loss: 0.1965/-0.0216
# Epoch: 012/020 | Batch 300/1272 | Gen/Dis Loss: -0.2706/-0.0312
# Epoch: 012/020 | Batch 400/1272 | Gen/Dis Loss: 0.2478/-0.0664
# Epoch: 012/020 | Batch 500/1272 | Gen/Dis Loss: 0.1838/-0.0746
# Epoch: 012/020 | Batch 600/1272 | Gen/Dis Loss: 0.3614/-0.0989
# Epoch: 012/020 | Batch 700/1272 | Gen/Dis Loss: 0.0031/-0.0452
# Epoch: 012/020 | Batch 800/1272 | Gen/Dis Loss: -0.2819/-0.0139
# Epoch: 012/020 | Batch 900/1272 | Gen/Dis Loss: 0.1358/-0.0730
# Epoch: 012/020 | Batch 1000/1272 | Gen/Dis Loss: 0.2387/-0.0193
# Epoch: 012/020 | Batch 1100/1272 | Gen/Dis Loss: 0.2425/-0.0633
# Epoch: 012/020 | Batch 1200/1272 | Gen/Dis Loss: 0.3089/-0.1077
# Time elapsed: 26.52 min
# Epoch: 013/020 | Batch 000/1272 | Gen/Dis Loss: 0.2032/-0.0625
# Epoch: 013/020 | Batch 100/1272 | Gen/Dis Loss: 0.1872/-0.0585
# Epoch: 013/020 | Batch 200/1272 | Gen/Dis Loss: 0.1640/-0.0655
# Epoch: 013/020 | Batch 300/1272 | Gen/Dis Loss: 0.3223/-0.1115
# Epoch: 013/020 | Batch 400/1272 | Gen/Dis Loss: 0.0584/-0.0202
# Epoch: 013/020 | Batch 500/1272 | Gen/Dis Loss: 0.2669/-0.0432
# Epoch: 013/020 | Batch 600/1272 | Gen/Dis Loss: 0.3594/-0.0993
# Epoch: 013/020 | Batch 700/1272 | Gen/Dis Loss: 0.0515/-0.0194
# Epoch: 013/020 | Batch 800/1272 | Gen/Dis Loss: -0.0772/-0.0142
# Epoch: 013/020 | Batch 900/1272 | Gen/Dis Loss: 0.2055/-0.0389
# Epoch: 013/020 | Batch 1000/1272 | Gen/Dis Loss: 0.1844/-0.0544
# Epoch: 013/020 | Batch 1100/1272 | Gen/Dis Loss: 0.2960/-0.0758
# Epoch: 013/020 | Batch 1200/1272 | Gen/Dis Loss: 0.4678/-0.1307
# Time elapsed: 28.73 min
# Epoch: 014/020 | Batch 000/1272 | Gen/Dis Loss: 0.0166/-0.1025
# Epoch: 014/020 | Batch 100/1272 | Gen/Dis Loss: 0.0862/-0.0543
# Epoch: 014/020 | Batch 200/1272 | Gen/Dis Loss: 0.3194/-0.0648
# Epoch: 014/020 | Batch 300/1272 | Gen/Dis Loss: 0.1754/-0.0963
# Epoch: 014/020 | Batch 400/1272 | Gen/Dis Loss: 0.1626/-0.0815
# Epoch: 014/020 | Batch 500/1272 | Gen/Dis Loss: 0.2521/-0.0720
# Epoch: 014/020 | Batch 600/1272 | Gen/Dis Loss: 0.2733/-0.1710
# Epoch: 014/020 | Batch 700/1272 | Gen/Dis Loss: 0.2663/-0.1502
# Epoch: 014/020 | Batch 800/1272 | Gen/Dis Loss: 0.3944/-0.1170
# Epoch: 014/020 | Batch 900/1272 | Gen/Dis Loss: 0.1925/-0.1455
# Epoch: 014/020 | Batch 1000/1272 | Gen/Dis Loss: 0.2916/-0.0579
# Epoch: 014/020 | Batch 1100/1272 | Gen/Dis Loss: 0.2790/-0.1129
# Epoch: 014/020 | Batch 1200/1272 | Gen/Dis Loss: 0.2738/-0.1313
# Time elapsed: 30.96 min
# Epoch: 015/020 | Batch 000/1272 | Gen/Dis Loss: 0.0247/-0.1807
# Epoch: 015/020 | Batch 100/1272 | Gen/Dis Loss: 0.4106/-0.1481
# Epoch: 015/020 | Batch 200/1272 | Gen/Dis Loss: 0.3429/-0.1777
# Epoch: 015/020 | Batch 300/1272 | Gen/Dis Loss: 0.2834/-0.2141
# Epoch: 015/020 | Batch 400/1272 | Gen/Dis Loss: 0.2607/-0.1481
# Epoch: 015/020 | Batch 500/1272 | Gen/Dis Loss: 0.4200/-0.1710
# Epoch: 015/020 | Batch 600/1272 | Gen/Dis Loss: 0.1377/-0.1776
# Epoch: 015/020 | Batch 700/1272 | Gen/Dis Loss: 0.2889/-0.1601
# Epoch: 015/020 | Batch 800/1272 | Gen/Dis Loss: 0.2982/-0.1624
# Epoch: 015/020 | Batch 900/1272 | Gen/Dis Loss: 0.1156/-0.1972
# Epoch: 015/020 | Batch 1000/1272 | Gen/Dis Loss: 0.3738/-0.1458
# Epoch: 015/020 | Batch 1100/1272 | Gen/Dis Loss: 0.1799/-0.1440
# Epoch: 015/020 | Batch 1200/1272 | Gen/Dis Loss: 0.3706/-0.1910
# Time elapsed: 33.18 min
# Epoch: 016/020 | Batch 000/1272 | Gen/Dis Loss: 0.1840/-0.1910
# Epoch: 016/020 | Batch 100/1272 | Gen/Dis Loss: 0.2787/-0.1150
# Epoch: 016/020 | Batch 200/1272 | Gen/Dis Loss: 0.4130/-0.1637
# Epoch: 016/020 | Batch 300/1272 | Gen/Dis Loss: 0.1638/-0.1488
# Epoch: 016/020 | Batch 400/1272 | Gen/Dis Loss: 0.3908/-0.1430
# Epoch: 016/020 | Batch 500/1272 | Gen/Dis Loss: 0.2216/-0.1637
# Epoch: 016/020 | Batch 600/1272 | Gen/Dis Loss: 0.2748/-0.1234
# Epoch: 016/020 | Batch 700/1272 | Gen/Dis Loss: 0.1905/-0.1065
# Epoch: 016/020 | Batch 800/1272 | Gen/Dis Loss: 0.2010/-0.1399
# Epoch: 016/020 | Batch 900/1272 | Gen/Dis Loss: 0.3047/-0.1683
# Epoch: 016/020 | Batch 1000/1272 | Gen/Dis Loss: 0.3499/-0.1287
# Epoch: 016/020 | Batch 1100/1272 | Gen/Dis Loss: 0.4129/-0.1391
# Epoch: 016/020 | Batch 1200/1272 | Gen/Dis Loss: 0.0601/-0.1561
# Time elapsed: 35.39 min
# Epoch: 017/020 | Batch 000/1272 | Gen/Dis Loss: 0.1410/-0.1915
# Epoch: 017/020 | Batch 100/1272 | Gen/Dis Loss: 0.2473/-0.1252
# Epoch: 017/020 | Batch 200/1272 | Gen/Dis Loss: 0.2915/-0.1347
# Epoch: 017/020 | Batch 300/1272 | Gen/Dis Loss: 0.2177/-0.1665
# Epoch: 017/020 | Batch 400/1272 | Gen/Dis Loss: 0.1461/-0.1601
# Epoch: 017/020 | Batch 500/1272 | Gen/Dis Loss: 0.2466/-0.1273
# Epoch: 017/020 | Batch 600/1272 | Gen/Dis Loss: 0.1244/-0.1454
# Epoch: 017/020 | Batch 700/1272 | Gen/Dis Loss: 0.2487/-0.0955
# Epoch: 017/020 | Batch 800/1272 | Gen/Dis Loss: 0.2432/-0.1177
# Epoch: 017/020 | Batch 900/1272 | Gen/Dis Loss: 0.1302/-0.1586
# Epoch: 017/020 | Batch 1000/1272 | Gen/Dis Loss: 0.2651/-0.1171
# Epoch: 017/020 | Batch 1100/1272 | Gen/Dis Loss: 0.3531/-0.1561
# Epoch: 017/020 | Batch 1200/1272 | Gen/Dis Loss: 0.1139/-0.1064
# Time elapsed: 37.60 min
# Epoch: 018/020 | Batch 000/1272 | Gen/Dis Loss: 0.3530/-0.1191
# Epoch: 018/020 | Batch 100/1272 | Gen/Dis Loss: 0.1551/-0.1059
# Epoch: 018/020 | Batch 200/1272 | Gen/Dis Loss: 0.2595/-0.0915
# Epoch: 018/020 | Batch 300/1272 | Gen/Dis Loss: 0.1004/-0.1236
# Epoch: 018/020 | Batch 400/1272 | Gen/Dis Loss: 0.2664/-0.1062
# Epoch: 018/020 | Batch 500/1272 | Gen/Dis Loss: 0.2933/-0.1141
# Epoch: 018/020 | Batch 600/1272 | Gen/Dis Loss: 0.3142/-0.1281
# Epoch: 018/020 | Batch 700/1272 | Gen/Dis Loss: 0.2519/-0.0480
# Epoch: 018/020 | Batch 800/1272 | Gen/Dis Loss: 0.2024/-0.1052
# Epoch: 018/020 | Batch 900/1272 | Gen/Dis Loss: 0.0951/-0.1211
# Epoch: 018/020 | Batch 1000/1272 | Gen/Dis Loss: 0.1887/-0.0925
# Epoch: 018/020 | Batch 1100/1272 | Gen/Dis Loss: 0.0986/-0.1402
# Epoch: 018/020 | Batch 1200/1272 | Gen/Dis Loss: 0.1698/-0.1322
# Time elapsed: 39.82 min
# Epoch: 019/020 | Batch 000/1272 | Gen/Dis Loss: 0.1401/-0.1340
# Epoch: 019/020 | Batch 100/1272 | Gen/Dis Loss: 0.1518/-0.0727
# Epoch: 019/020 | Batch 200/1272 | Gen/Dis Loss: 0.2610/-0.1428
# Epoch: 019/020 | Batch 300/1272 | Gen/Dis Loss: 0.1522/-0.1035
# Epoch: 019/020 | Batch 400/1272 | Gen/Dis Loss: 0.2255/-0.0817
# Epoch: 019/020 | Batch 500/1272 | Gen/Dis Loss: 0.2359/-0.0886
# Epoch: 019/020 | Batch 600/1272 | Gen/Dis Loss: 0.0976/-0.1327
# Epoch: 019/020 | Batch 700/1272 | Gen/Dis Loss: 0.2121/-0.0985
# Epoch: 019/020 | Batch 800/1272 | Gen/Dis Loss: 0.3064/-0.1237
# Epoch: 019/020 | Batch 900/1272 | Gen/Dis Loss: 0.3021/-0.0978
# Epoch: 019/020 | Batch 1000/1272 | Gen/Dis Loss: 0.2741/-0.0832
# Epoch: 019/020 | Batch 1100/1272 | Gen/Dis Loss: 0.3344/-0.1100
# Epoch: 019/020 | Batch 1200/1272 | Gen/Dis Loss: 0.2771/-0.0957
# Time elapsed: 42.04 min
# Epoch: 020/020 | Batch 000/1272 | Gen/Dis Loss: 0.0587/-0.0867
# Epoch: 020/020 | Batch 100/1272 | Gen/Dis Loss: 0.2660/-0.1044
# Epoch: 020/020 | Batch 200/1272 | Gen/Dis Loss: 0.0215/-0.1373
# Epoch: 020/020 | Batch 300/1272 | Gen/Dis Loss: 0.2574/-0.1285
# Epoch: 020/020 | Batch 400/1272 | Gen/Dis Loss: 0.0983/-0.0268
# Epoch: 020/020 | Batch 500/1272 | Gen/Dis Loss: 0.0718/-0.0731
# Epoch: 020/020 | Batch 600/1272 | Gen/Dis Loss: 0.1660/-0.0846
# Epoch: 020/020 | Batch 700/1272 | Gen/Dis Loss: 0.2954/-0.0899
# Epoch: 020/020 | Batch 800/1272 | Gen/Dis Loss: 0.2864/-0.1353
# Epoch: 020/020 | Batch 900/1272 | Gen/Dis Loss: 0.2160/-0.1576
# Epoch: 020/020 | Batch 1000/1272 | Gen/Dis Loss: 0.2062/-0.0760
# Epoch: 020/020 | Batch 1100/1272 | Gen/Dis Loss: 0.0803/-0.1445
# Epoch: 020/020 | Batch 1200/1272 | Gen/Dis Loss: 0.1891/-0.1147
# Time elapsed: 44.25 min
# Total Training Time: 44.25 min

# %% [markdown]
# ## Evaluation

# %%
plot_multiple_training_losses(
    losses_list=(log_dict['train_discriminator_loss_per_batch'],
                 log_dict['train_generator_loss_per_batch']),
    num_epochs=NUM_EPOCHS, 
    custom_labels_list=(' -- Discriminator', ' -- Generator')
)

# %%
##########################
### VISUALIZATION
##########################

for i in range(0, NUM_EPOCHS, 5):
    
    plt.figure(figsize=(8, 8))
    plt.axis('off')
    plt.title(f'Generated images at epoch {i}')
    plt.imshow(np.transpose(log_dict['images_from_noise_per_epoch'][i], (1, 2, 0)))
    plt.show()
    
    
plt.figure(figsize=(8, 8))
plt.axis('off')
plt.title(f'Generated images after last epoch')
plt.imshow(np.transpose(log_dict['images_from_noise_per_epoch'][-1], (1, 2, 0)))
plt.show()
