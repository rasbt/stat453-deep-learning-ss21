# %% [markdown]
# STAT 453: Deep Learning (Spring 2021)
# Instructor: Sebastian Raschka (sraschka@wisc.edu)
#
# Course website: http://pages.stat.wisc.edu/~sraschka/teaching/stat453-ss2021/
# GitHub repository: https://github.com/rasbt/stat453-deep-learning-ss21
#
# ---

# %% [markdown]
# # Deep Convolutional GAN Trained on CelebA

# %%
# %load_ext watermark
# %watermark -a 'Sebastian Raschka' -v -p torch
# Out:
# Author: Sebastian Raschka
#
# Python implementation: CPython
# Python version       : 3.8.8
# IPython version      : 7.21.0
#
# torch: 1.8.1+cu111

# %% [markdown]
# ## Imports

# %%
import numpy as np
import torch
import torchvision
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# #### Import utility functions

# %%
from helper_data import get_dataloaders_celeba
from helper_train import train_gan_v1
from helper_utils import set_deterministic, set_all_seeds
from helper_plotting import plot_multiple_training_losses
from helper_plotting import plot_generated_images

# %%
##########################
### SETTINGS
##########################

# Device
CUDA_DEVICE_NUM = 1
DEVICE = torch.device(f'cuda:{CUDA_DEVICE_NUM}' if torch.cuda.is_available() else 'cpu')
print('Device:', DEVICE)

# Hyperparameters
RANDOM_SEED = 42
GENERATOR_LEARNING_RATE = 0.0002
DISCRIMINATOR_LEARNING_RATE = 0.0002

NUM_EPOCHS = 20
BATCH_SIZE = 128

IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS = 64, 64, 3
# Out:
# Device: cuda:1

# %%
set_deterministic
set_all_seeds(RANDOM_SEED)

# %% [markdown]
# ## Dataset

# %%
##########################
### Dataset
##########################


custom_transforms = torchvision.transforms.Compose([
    torchvision.transforms.CenterCrop((160, 160)),
    torchvision.transforms.Resize([IMAGE_HEIGHT, IMAGE_WIDTH]),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])


train_loader, valid_loader, test_loader = get_dataloaders_celeba(
    batch_size=BATCH_SIZE,
    train_transforms=custom_transforms,
    test_transforms=custom_transforms,
    num_workers=4)
# Out:
# Files already downloaded and verified

# %%
# Checking the dataset
print('Training Set:\n')
for images, labels in train_loader:  
    print('Image batch dimensions:', images.size())
    print('Image label dimensions:', labels.size())
    #print(labels[:10])
    break
    
# Checking the dataset
print('\nValidation Set:')
for images, labels in valid_loader:  
    print('Image batch dimensions:', images.size())
    print('Image label dimensions:', labels.size())
    #print(labels[:10])
    break

# Checking the dataset
print('\nTesting Set:')
for images, labels in test_loader:  
    print('Image batch dimensions:', images.size())
    print('Image label dimensions:', labels.size())
    #print(labels[:10])
    break
# Out:
# Training Set:
#
# Image batch dimensions: torch.Size([128, 3, 64, 64])
# Image label dimensions: torch.Size([128, 40])
#
# Validation Set:
# Image batch dimensions: torch.Size([128, 3, 64, 64])
# Image label dimensions: torch.Size([128, 40])
#
# Testing Set:
# Image batch dimensions: torch.Size([128, 3, 64, 64])
# Image label dimensions: torch.Size([128, 40])

# %%
plt.figure(figsize=(8, 8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(torchvision.utils.make_grid(images[:64], 
                                         padding=2, normalize=True),
                        (1, 2, 0)))

# %% [markdown]
# ## Model

# %%
##########################
### MODEL
##########################

class DCGAN(torch.nn.Module):

    def __init__(self, latent_dim=100, 
                 num_feat_maps_gen=64, num_feat_maps_dis=64,
                 color_channels=3):
        super().__init__()
        
        
        self.generator = nn.Sequential(
            nn.ConvTranspose2d(latent_dim, num_feat_maps_gen*8, 
                               kernel_size=4, stride=1, padding=0,
                               bias=False),
            nn.BatchNorm2d(num_feat_maps_gen*8),
            nn.ReLU(inplace=True),
            #
            # size if latent_dim=100: num_feat_maps_gen*8 x 4 x 4
            #
            nn.ConvTranspose2d(num_feat_maps_gen*8, num_feat_maps_gen*4, 
                               kernel_size=4, stride=2, padding=1,
                               bias=False),
            nn.BatchNorm2d(num_feat_maps_gen*4),
            nn.ReLU(inplace=True),
            #
            # size if latent_dim=100: num_feat_maps_gen*4 x 8 x 8
            #
            nn.ConvTranspose2d(num_feat_maps_gen*4, num_feat_maps_gen*2, 
                               kernel_size=4, stride=2, padding=1,
                               bias=False),
            nn.BatchNorm2d(num_feat_maps_gen*2),
            nn.ReLU(inplace=True),
            #
            # size if latent_dim=100: num_feat_maps_gen*2 x 16 x 16
            #
            nn.ConvTranspose2d(num_feat_maps_gen*2, num_feat_maps_gen, 
                               kernel_size=4, stride=2, padding=1,
                               bias=False),
            nn.BatchNorm2d(num_feat_maps_gen),
            nn.ReLU(inplace=True),   
            #
            # size if latent_dim=100: num_feat_maps_gen x 32 x 32
            #
            nn.ConvTranspose2d(num_feat_maps_gen, color_channels, 
                               kernel_size=4, stride=2, padding=1,
                               bias=False),
            #
            # size: color_channels x 64 x 64
            #  
            nn.Tanh()
        )
        
        self.discriminator = nn.Sequential(
            #
            # input size color_channels x image_height x image_width
            #
            nn.Conv2d(color_channels, num_feat_maps_dis,
                      kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            #
            # size: num_feat_maps_dis x 32 x 32
            #              
            nn.Conv2d(num_feat_maps_dis, num_feat_maps_dis*2,
                      kernel_size=4, stride=2, padding=1,
                      bias=False),        
            nn.BatchNorm2d(num_feat_maps_dis*2),
            nn.LeakyReLU(0.2, inplace=True),
            #
            # size: num_feat_maps_dis*2 x 16 x 16
            #   
            nn.Conv2d(num_feat_maps_dis*2, num_feat_maps_dis*4,
                      kernel_size=4, stride=2, padding=1,
                      bias=False),        
            nn.BatchNorm2d(num_feat_maps_dis*4),
            nn.LeakyReLU(0.2, inplace=True),
            #
            # size: num_feat_maps_dis*4 x 8 x 8
            #   
            nn.Conv2d(num_feat_maps_dis*4, num_feat_maps_dis*8,
                      kernel_size=4, stride=2, padding=1,
                      bias=False),        
            nn.BatchNorm2d(num_feat_maps_dis*8),
            nn.LeakyReLU(0.2, inplace=True),
            #
            # size: num_feat_maps_dis*8 x 4 x 4
            #   
            nn.Conv2d(num_feat_maps_dis*8, 1,
                      kernel_size=4, stride=1, padding=0),
            
            # size: 1 x 1 x 1
            nn.Flatten(),
            
        )

            
    def generator_forward(self, z):
        img = self.generator(z)
        return img
    
    def discriminator_forward(self, img):
        logits = model.discriminator(img)
        return logits

# %%
set_all_seeds(RANDOM_SEED)

model = DCGAN()
model.to(DEVICE)


optim_gen = torch.optim.Adam(model.generator.parameters(),
                             betas=(0.5, 0.999),
                             lr=GENERATOR_LEARNING_RATE)

optim_discr = torch.optim.Adam(model.discriminator.parameters(),
                               betas=(0.5, 0.999),
                               lr=DISCRIMINATOR_LEARNING_RATE)

# %% [markdown]
# ## Training

# %%
log_dict = train_gan_v1(num_epochs=NUM_EPOCHS, model=model, 
                        optimizer_gen=optim_gen,
                        optimizer_discr=optim_discr,
                        device=DEVICE, 
                        train_loader=train_loader,
                        logging_interval=100,
                        save_model='gan_celeba_01.pt')
# Out:
# Epoch: 001/020 | Batch 000/1272 | Gen/Dis Loss: 2.3317/0.7514
# Epoch: 001/020 | Batch 100/1272 | Gen/Dis Loss: 2.5685/0.1804
# Epoch: 001/020 | Batch 200/1272 | Gen/Dis Loss: 4.1259/0.2531
# Epoch: 001/020 | Batch 300/1272 | Gen/Dis Loss: 4.1189/0.6983
# Epoch: 001/020 | Batch 400/1272 | Gen/Dis Loss: 4.2652/0.2299
# Epoch: 001/020 | Batch 500/1272 | Gen/Dis Loss: 2.0144/0.4778
# Epoch: 001/020 | Batch 600/1272 | Gen/Dis Loss: 3.3571/0.2449
# Epoch: 001/020 | Batch 700/1272 | Gen/Dis Loss: 2.4522/0.3027
# Epoch: 001/020 | Batch 800/1272 | Gen/Dis Loss: 3.1422/0.2924
# Epoch: 001/020 | Batch 900/1272 | Gen/Dis Loss: 3.1091/0.2714
# Epoch: 001/020 | Batch 1000/1272 | Gen/Dis Loss: 2.7235/0.3220
# Epoch: 001/020 | Batch 1100/1272 | Gen/Dis Loss: 2.4519/0.2767
# Epoch: 001/020 | Batch 1200/1272 | Gen/Dis Loss: 2.1475/0.7924
# Time elapsed: 2.37 min
# Epoch: 002/020 | Batch 000/1272 | Gen/Dis Loss: 5.6568/0.4524
# Epoch: 002/020 | Batch 100/1272 | Gen/Dis Loss: 2.6788/0.1847
# Epoch: 002/020 | Batch 200/1272 | Gen/Dis Loss: 3.6602/0.3040
# Epoch: 002/020 | Batch 300/1272 | Gen/Dis Loss: 4.4092/0.3032
# Epoch: 002/020 | Batch 400/1272 | Gen/Dis Loss: 2.0663/0.2437
# Epoch: 002/020 | Batch 500/1272 | Gen/Dis Loss: 4.2390/0.2536
# Epoch: 002/020 | Batch 600/1272 | Gen/Dis Loss: 5.0321/0.3873
# Epoch: 002/020 | Batch 700/1272 | Gen/Dis Loss: 1.7769/0.2946
# Epoch: 002/020 | Batch 800/1272 | Gen/Dis Loss: 3.7952/0.2760
# Epoch: 002/020 | Batch 900/1272 | Gen/Dis Loss: 4.0205/0.3445
# Epoch: 002/020 | Batch 1000/1272 | Gen/Dis Loss: 4.3175/0.2149
# Epoch: 002/020 | Batch 1100/1272 | Gen/Dis Loss: 2.0020/0.2912
# Epoch: 002/020 | Batch 1200/1272 | Gen/Dis Loss: 3.4722/0.2645
# Time elapsed: 4.73 min
# Epoch: 003/020 | Batch 000/1272 | Gen/Dis Loss: 3.5261/0.2375
# Epoch: 003/020 | Batch 100/1272 | Gen/Dis Loss: 2.6798/0.2720
# Epoch: 003/020 | Batch 200/1272 | Gen/Dis Loss: 1.3487/0.2538
# Epoch: 003/020 | Batch 300/1272 | Gen/Dis Loss: 4.3994/0.1939
# Epoch: 003/020 | Batch 400/1272 | Gen/Dis Loss: 0.2912/0.9294
# Epoch: 003/020 | Batch 500/1272 | Gen/Dis Loss: 1.3276/0.4433
# Epoch: 003/020 | Batch 600/1272 | Gen/Dis Loss: 1.4998/0.4066
# Epoch: 003/020 | Batch 700/1272 | Gen/Dis Loss: 4.2067/0.1759
# Epoch: 003/020 | Batch 800/1272 | Gen/Dis Loss: 3.1077/0.1317
# Epoch: 003/020 | Batch 900/1272 | Gen/Dis Loss: 3.9679/0.2453
# Epoch: 003/020 | Batch 1000/1272 | Gen/Dis Loss: 4.4344/0.3157
# Epoch: 003/020 | Batch 1100/1272 | Gen/Dis Loss: 3.5498/0.2784
# Epoch: 003/020 | Batch 1200/1272 | Gen/Dis Loss: 6.4911/0.5744
# Time elapsed: 7.08 min
# Epoch: 004/020 | Batch 000/1272 | Gen/Dis Loss: 2.0837/0.2227
# Epoch: 004/020 | Batch 100/1272 | Gen/Dis Loss: 3.0895/0.1725
# Epoch: 004/020 | Batch 200/1272 | Gen/Dis Loss: 3.2542/0.3694
# Epoch: 004/020 | Batch 300/1272 | Gen/Dis Loss: 4.5946/0.1375
# Epoch: 004/020 | Batch 400/1272 | Gen/Dis Loss: 6.6609/0.3778
# Epoch: 004/020 | Batch 500/1272 | Gen/Dis Loss: 3.8055/0.1194
# Epoch: 004/020 | Batch 600/1272 | Gen/Dis Loss: 3.7298/0.0797
# Epoch: 004/020 | Batch 700/1272 | Gen/Dis Loss: 2.3726/0.1639
# Epoch: 004/020 | Batch 800/1272 | Gen/Dis Loss: 2.5223/0.1774
# Epoch: 004/020 | Batch 900/1272 | Gen/Dis Loss: 4.1558/0.1762
# Epoch: 004/020 | Batch 1000/1272 | Gen/Dis Loss: 1.9867/0.2192
# Epoch: 004/020 | Batch 1100/1272 | Gen/Dis Loss: 2.5379/0.1057
# Epoch: 004/020 | Batch 1200/1272 | Gen/Dis Loss: 5.4331/0.2110
# Time elapsed: 9.44 min
# Epoch: 005/020 | Batch 000/1272 | Gen/Dis Loss: 4.8042/0.2085
# Epoch: 005/020 | Batch 100/1272 | Gen/Dis Loss: 4.2012/0.1777
# Epoch: 005/020 | Batch 200/1272 | Gen/Dis Loss: 3.0088/0.2483
# Epoch: 005/020 | Batch 300/1272 | Gen/Dis Loss: 3.5110/0.0875
# Epoch: 005/020 | Batch 400/1272 | Gen/Dis Loss: 3.2095/0.0622
# Epoch: 005/020 | Batch 500/1272 | Gen/Dis Loss: 4.9653/0.1841
# Epoch: 005/020 | Batch 600/1272 | Gen/Dis Loss: 4.2451/0.0557
# Epoch: 005/020 | Batch 700/1272 | Gen/Dis Loss: 2.7075/0.2145
# Epoch: 005/020 | Batch 800/1272 | Gen/Dis Loss: 1.4319/0.5642
# Epoch: 005/020 | Batch 900/1272 | Gen/Dis Loss: 3.2713/0.1105
# Epoch: 005/020 | Batch 1000/1272 | Gen/Dis Loss: 3.5095/0.1851
# Epoch: 005/020 | Batch 1100/1272 | Gen/Dis Loss: 4.3332/0.0499
# Epoch: 005/020 | Batch 1200/1272 | Gen/Dis Loss: 4.1094/0.2352
# Time elapsed: 11.80 min
# Epoch: 006/020 | Batch 000/1272 | Gen/Dis Loss: 3.9219/0.0553
# Epoch: 006/020 | Batch 100/1272 | Gen/Dis Loss: 2.6102/0.2973
# Epoch: 006/020 | Batch 200/1272 | Gen/Dis Loss: 6.5536/0.4060
# Epoch: 006/020 | Batch 300/1272 | Gen/Dis Loss: 3.8920/0.0781
# Epoch: 006/020 | Batch 400/1272 | Gen/Dis Loss: 4.1064/0.0512
# Epoch: 006/020 | Batch 500/1272 | Gen/Dis Loss: 5.2126/0.1168
# Epoch: 006/020 | Batch 600/1272 | Gen/Dis Loss: 0.6220/0.8459
# Epoch: 006/020 | Batch 700/1272 | Gen/Dis Loss: 0.4037/0.7628
# Epoch: 006/020 | Batch 800/1272 | Gen/Dis Loss: 4.6358/0.0708
# Epoch: 006/020 | Batch 900/1272 | Gen/Dis Loss: 5.5203/0.1634
# Epoch: 006/020 | Batch 1000/1272 | Gen/Dis Loss: 0.7017/1.4008
# Epoch: 006/020 | Batch 1100/1272 | Gen/Dis Loss: 3.9352/0.0327
# Epoch: 006/020 | Batch 1200/1272 | Gen/Dis Loss: 3.9034/0.0768
# Time elapsed: 14.16 min
# Epoch: 007/020 | Batch 000/1272 | Gen/Dis Loss: 5.6183/0.0784
# Epoch: 007/020 | Batch 100/1272 | Gen/Dis Loss: 7.0121/0.4837
# Epoch: 007/020 | Batch 200/1272 | Gen/Dis Loss: 4.1433/0.0816
# Epoch: 007/020 | Batch 300/1272 | Gen/Dis Loss: 2.6459/0.1179
# Epoch: 007/020 | Batch 400/1272 | Gen/Dis Loss: 4.0709/0.0771
# Epoch: 007/020 | Batch 500/1272 | Gen/Dis Loss: 4.0793/0.0645
# Epoch: 007/020 | Batch 600/1272 | Gen/Dis Loss: 2.2928/0.1500
# Epoch: 007/020 | Batch 700/1272 | Gen/Dis Loss: 3.2550/0.3241
# Epoch: 007/020 | Batch 800/1272 | Gen/Dis Loss: 2.1801/0.1271
# Epoch: 007/020 | Batch 900/1272 | Gen/Dis Loss: 4.2468/0.0435
# Epoch: 007/020 | Batch 1000/1272 | Gen/Dis Loss: 5.1790/0.1014
# Epoch: 007/020 | Batch 1100/1272 | Gen/Dis Loss: 3.0422/0.0613
# Epoch: 007/020 | Batch 1200/1272 | Gen/Dis Loss: 4.3824/0.0400
# Time elapsed: 16.52 min
# Epoch: 008/020 | Batch 000/1272 | Gen/Dis Loss: 4.8070/0.0265
# Epoch: 008/020 | Batch 100/1272 | Gen/Dis Loss: 4.1117/0.0860
# Epoch: 008/020 | Batch 200/1272 | Gen/Dis Loss: 4.3719/0.0619
# Epoch: 008/020 | Batch 300/1272 | Gen/Dis Loss: 3.7224/0.1797
# Epoch: 008/020 | Batch 400/1272 | Gen/Dis Loss: 0.5929/0.7472
# Epoch: 008/020 | Batch 500/1272 | Gen/Dis Loss: 6.3712/0.0704
# Epoch: 008/020 | Batch 600/1272 | Gen/Dis Loss: 3.9336/0.0368
# Epoch: 008/020 | Batch 700/1272 | Gen/Dis Loss: 3.9848/0.0793
# Epoch: 008/020 | Batch 800/1272 | Gen/Dis Loss: 4.5898/0.0418
# Epoch: 008/020 | Batch 900/1272 | Gen/Dis Loss: 4.2883/0.1448
# Epoch: 008/020 | Batch 1000/1272 | Gen/Dis Loss: 0.0213/3.4283
# Epoch: 008/020 | Batch 1100/1272 | Gen/Dis Loss: 4.6327/0.0477
# Epoch: 008/020 | Batch 1200/1272 | Gen/Dis Loss: 3.6414/0.0730
# Time elapsed: 18.87 min
# Epoch: 009/020 | Batch 000/1272 | Gen/Dis Loss: 4.7801/0.1280
# Epoch: 009/020 | Batch 100/1272 | Gen/Dis Loss: 4.2322/0.0517
# Epoch: 009/020 | Batch 200/1272 | Gen/Dis Loss: 3.8333/0.0287
# Epoch: 009/020 | Batch 300/1272 | Gen/Dis Loss: 5.0385/0.0694
# Epoch: 009/020 | Batch 400/1272 | Gen/Dis Loss: 5.0192/0.0401
# Epoch: 009/020 | Batch 500/1272 | Gen/Dis Loss: 4.6647/0.0242
# Epoch: 009/020 | Batch 600/1272 | Gen/Dis Loss: 3.2025/0.1112
# Epoch: 009/020 | Batch 700/1272 | Gen/Dis Loss: 4.2556/0.0511
# Epoch: 009/020 | Batch 800/1272 | Gen/Dis Loss: 3.7648/0.1229
# Epoch: 009/020 | Batch 900/1272 | Gen/Dis Loss: 4.8526/0.0248
# Epoch: 009/020 | Batch 1000/1272 | Gen/Dis Loss: 3.9001/0.0542
# Epoch: 009/020 | Batch 1100/1272 | Gen/Dis Loss: 5.6036/0.1054
# Epoch: 009/020 | Batch 1200/1272 | Gen/Dis Loss: 4.8873/0.0433
# Time elapsed: 21.23 min
# Epoch: 010/020 | Batch 000/1272 | Gen/Dis Loss: 1.7578/0.3460
# Epoch: 010/020 | Batch 100/1272 | Gen/Dis Loss: 4.4231/0.0642
# Epoch: 010/020 | Batch 200/1272 | Gen/Dis Loss: 4.2984/0.0129
# Epoch: 010/020 | Batch 300/1272 | Gen/Dis Loss: 4.2130/0.0849
# Epoch: 010/020 | Batch 400/1272 | Gen/Dis Loss: 4.7625/0.0159
# Epoch: 010/020 | Batch 500/1272 | Gen/Dis Loss: 1.4691/0.2119
# Epoch: 010/020 | Batch 600/1272 | Gen/Dis Loss: 4.4353/0.0911
# Epoch: 010/020 | Batch 700/1272 | Gen/Dis Loss: 14.5723/2.2583
# Epoch: 010/020 | Batch 800/1272 | Gen/Dis Loss: 3.6050/0.0896
# Epoch: 010/020 | Batch 900/1272 | Gen/Dis Loss: 4.9534/0.0503
# Epoch: 010/020 | Batch 1000/1272 | Gen/Dis Loss: 4.1015/0.1352
# Epoch: 010/020 | Batch 1100/1272 | Gen/Dis Loss: 5.3644/0.0171
# Epoch: 010/020 | Batch 1200/1272 | Gen/Dis Loss: 4.7203/0.0276
# Time elapsed: 23.60 min
# Epoch: 011/020 | Batch 000/1272 | Gen/Dis Loss: 5.4082/0.0536
# Epoch: 011/020 | Batch 100/1272 | Gen/Dis Loss: 4.3222/0.0570
# Epoch: 011/020 | Batch 200/1272 | Gen/Dis Loss: 3.0361/0.0669
# Epoch: 011/020 | Batch 300/1272 | Gen/Dis Loss: 4.9214/0.0391
# Epoch: 011/020 | Batch 400/1272 | Gen/Dis Loss: 7.2024/0.2942
# Epoch: 011/020 | Batch 500/1272 | Gen/Dis Loss: 4.9216/0.0265
# Epoch: 011/020 | Batch 600/1272 | Gen/Dis Loss: 5.1080/0.0388
# Epoch: 011/020 | Batch 700/1272 | Gen/Dis Loss: 5.1338/0.0209
# Epoch: 011/020 | Batch 800/1272 | Gen/Dis Loss: 6.6684/0.0383
# Epoch: 011/020 | Batch 900/1272 | Gen/Dis Loss: 5.8246/0.3736
# Epoch: 011/020 | Batch 1000/1272 | Gen/Dis Loss: 5.0776/0.0431
# Epoch: 011/020 | Batch 1100/1272 | Gen/Dis Loss: 5.0001/0.1581
# Epoch: 011/020 | Batch 1200/1272 | Gen/Dis Loss: 5.1597/0.0538
# Time elapsed: 25.95 min
# Epoch: 012/020 | Batch 000/1272 | Gen/Dis Loss: 5.8999/0.0392
# Epoch: 012/020 | Batch 100/1272 | Gen/Dis Loss: 5.5116/0.0151
# Epoch: 012/020 | Batch 200/1272 | Gen/Dis Loss: 4.9189/0.0323
# Epoch: 012/020 | Batch 300/1272 | Gen/Dis Loss: 4.1127/0.0282
# Epoch: 012/020 | Batch 400/1272 | Gen/Dis Loss: 5.8754/0.0136
# Epoch: 012/020 | Batch 500/1272 | Gen/Dis Loss: 4.9962/0.0436
# Epoch: 012/020 | Batch 600/1272 | Gen/Dis Loss: 4.1986/0.0723
# Epoch: 012/020 | Batch 700/1272 | Gen/Dis Loss: 4.8762/0.0223
# Epoch: 012/020 | Batch 800/1272 | Gen/Dis Loss: 6.0491/0.0196
# Epoch: 012/020 | Batch 900/1272 | Gen/Dis Loss: 4.4679/0.0303
# Epoch: 012/020 | Batch 1000/1272 | Gen/Dis Loss: 3.9539/0.0566
# Epoch: 012/020 | Batch 1100/1272 | Gen/Dis Loss: 6.1730/0.1162
# Epoch: 012/020 | Batch 1200/1272 | Gen/Dis Loss: 4.1291/0.1018
# Time elapsed: 28.32 min
# Epoch: 013/020 | Batch 000/1272 | Gen/Dis Loss: 5.1704/0.0216
# Epoch: 013/020 | Batch 100/1272 | Gen/Dis Loss: 6.5592/0.0185
# Epoch: 013/020 | Batch 200/1272 | Gen/Dis Loss: 5.3944/0.0218
# Epoch: 013/020 | Batch 300/1272 | Gen/Dis Loss: 4.6819/0.0222
# Epoch: 013/020 | Batch 400/1272 | Gen/Dis Loss: 7.8371/0.0891
# Epoch: 013/020 | Batch 500/1272 | Gen/Dis Loss: 5.6609/0.0337
# Epoch: 013/020 | Batch 600/1272 | Gen/Dis Loss: 4.9493/0.0168
# Epoch: 013/020 | Batch 700/1272 | Gen/Dis Loss: 2.2539/0.3497
# Epoch: 013/020 | Batch 800/1272 | Gen/Dis Loss: 3.9331/0.1113
# Epoch: 013/020 | Batch 900/1272 | Gen/Dis Loss: 4.3978/0.0324
# Epoch: 013/020 | Batch 1000/1272 | Gen/Dis Loss: 4.8096/0.0298
# Epoch: 013/020 | Batch 1100/1272 | Gen/Dis Loss: 4.4911/0.0495
# Epoch: 013/020 | Batch 1200/1272 | Gen/Dis Loss: 5.4237/0.1152
# Time elapsed: 30.68 min
# Epoch: 014/020 | Batch 000/1272 | Gen/Dis Loss: 5.6139/0.0295
# Epoch: 014/020 | Batch 100/1272 | Gen/Dis Loss: 5.4571/0.0479
# Epoch: 014/020 | Batch 200/1272 | Gen/Dis Loss: 5.9407/0.0266
# Epoch: 014/020 | Batch 300/1272 | Gen/Dis Loss: 5.2527/0.0617
# Epoch: 014/020 | Batch 400/1272 | Gen/Dis Loss: 7.9479/2.2572
# Epoch: 014/020 | Batch 500/1272 | Gen/Dis Loss: 5.9403/0.0136
# Epoch: 014/020 | Batch 600/1272 | Gen/Dis Loss: 7.2700/0.0036
# Epoch: 014/020 | Batch 700/1272 | Gen/Dis Loss: 8.5419/0.0017
# Epoch: 014/020 | Batch 800/1272 | Gen/Dis Loss: 8.7848/0.0029
# Epoch: 014/020 | Batch 900/1272 | Gen/Dis Loss: 8.6704/0.0004
# Epoch: 014/020 | Batch 1000/1272 | Gen/Dis Loss: 8.5927/0.0002
# Epoch: 014/020 | Batch 1100/1272 | Gen/Dis Loss: 9.3392/0.0001
# Epoch: 014/020 | Batch 1200/1272 | Gen/Dis Loss: 10.5170/0.0001
# Time elapsed: 33.03 min
# Epoch: 015/020 | Batch 000/1272 | Gen/Dis Loss: 13.7825/0.0000
# Epoch: 015/020 | Batch 100/1272 | Gen/Dis Loss: 29.2021/0.0114
# Epoch: 015/020 | Batch 200/1272 | Gen/Dis Loss: 24.3390/0.4033
# Epoch: 015/020 | Batch 300/1272 | Gen/Dis Loss: 9.2236/0.0033
# Epoch: 015/020 | Batch 400/1272 | Gen/Dis Loss: 49.7712/0.1912
# Epoch: 015/020 | Batch 500/1272 | Gen/Dis Loss: 27.3014/0.0000
# Epoch: 015/020 | Batch 600/1272 | Gen/Dis Loss: 38.1799/0.6705
# Epoch: 015/020 | Batch 700/1272 | Gen/Dis Loss: 21.6768/0.0018
# Epoch: 015/020 | Batch 800/1272 | Gen/Dis Loss: 13.1338/0.0314
# Epoch: 015/020 | Batch 900/1272 | Gen/Dis Loss: 20.1968/0.0004
# Epoch: 015/020 | Batch 1000/1272 | Gen/Dis Loss: 8.7025/0.0281
# Epoch: 015/020 | Batch 1100/1272 | Gen/Dis Loss: 10.0984/0.0015
# Epoch: 015/020 | Batch 1200/1272 | Gen/Dis Loss: 6.3220/0.0278
# Time elapsed: 35.40 min
# Epoch: 016/020 | Batch 000/1272 | Gen/Dis Loss: 19.6560/0.0946
# Epoch: 016/020 | Batch 100/1272 | Gen/Dis Loss: 6.7027/0.0052
# Epoch: 016/020 | Batch 200/1272 | Gen/Dis Loss: 8.8817/0.0041
# Epoch: 016/020 | Batch 300/1272 | Gen/Dis Loss: 8.3365/0.0169
# Epoch: 016/020 | Batch 400/1272 | Gen/Dis Loss: 7.1634/0.0085
# Epoch: 016/020 | Batch 500/1272 | Gen/Dis Loss: 9.0389/0.0015
# Epoch: 016/020 | Batch 600/1272 | Gen/Dis Loss: 9.0981/0.0003
# Epoch: 016/020 | Batch 700/1272 | Gen/Dis Loss: 8.6911/0.0058
# Epoch: 016/020 | Batch 800/1272 | Gen/Dis Loss: 12.1613/0.0010
# Epoch: 016/020 | Batch 900/1272 | Gen/Dis Loss: 8.2065/0.0061
# Epoch: 016/020 | Batch 1000/1272 | Gen/Dis Loss: 8.3700/0.0076
# Epoch: 016/020 | Batch 1100/1272 | Gen/Dis Loss: 10.3712/0.0118
# Epoch: 016/020 | Batch 1200/1272 | Gen/Dis Loss: 9.5777/0.0009
# Time elapsed: 37.76 min
# Epoch: 017/020 | Batch 000/1272 | Gen/Dis Loss: 7.5964/0.0149
# Epoch: 017/020 | Batch 100/1272 | Gen/Dis Loss: 10.9997/0.0059
# Epoch: 017/020 | Batch 200/1272 | Gen/Dis Loss: 7.8446/0.0071
# Epoch: 017/020 | Batch 300/1272 | Gen/Dis Loss: 11.1813/0.0297
# Epoch: 017/020 | Batch 400/1272 | Gen/Dis Loss: 11.6330/0.0071
# Epoch: 017/020 | Batch 500/1272 | Gen/Dis Loss: 8.2314/0.0101
# Epoch: 017/020 | Batch 600/1272 | Gen/Dis Loss: 9.5406/0.0409
# Epoch: 017/020 | Batch 700/1272 | Gen/Dis Loss: 8.6412/0.0022
# Epoch: 017/020 | Batch 800/1272 | Gen/Dis Loss: 8.2092/0.0038
# Epoch: 017/020 | Batch 900/1272 | Gen/Dis Loss: 7.2065/0.0180
# Epoch: 017/020 | Batch 1000/1272 | Gen/Dis Loss: 6.9458/0.0050
# Epoch: 017/020 | Batch 1100/1272 | Gen/Dis Loss: 6.4226/0.0197
# Epoch: 017/020 | Batch 1200/1272 | Gen/Dis Loss: 12.0828/0.0276
# Time elapsed: 40.12 min
# Epoch: 018/020 | Batch 000/1272 | Gen/Dis Loss: 5.6057/0.0246
# Epoch: 018/020 | Batch 100/1272 | Gen/Dis Loss: 16.4702/0.0182
# Epoch: 018/020 | Batch 200/1272 | Gen/Dis Loss: 7.0435/0.0063
# Epoch: 018/020 | Batch 300/1272 | Gen/Dis Loss: 7.3770/0.0030
# Epoch: 018/020 | Batch 400/1272 | Gen/Dis Loss: 4.1650/0.0329
# Epoch: 018/020 | Batch 500/1272 | Gen/Dis Loss: 12.8423/0.0219
# Epoch: 018/020 | Batch 600/1272 | Gen/Dis Loss: 8.3283/0.0103
# Epoch: 018/020 | Batch 700/1272 | Gen/Dis Loss: 14.4952/0.0363
# Epoch: 018/020 | Batch 800/1272 | Gen/Dis Loss: 8.3826/0.0084
# Epoch: 018/020 | Batch 900/1272 | Gen/Dis Loss: 6.7812/0.0114
# Epoch: 018/020 | Batch 1000/1272 | Gen/Dis Loss: 8.2391/0.0027
# Epoch: 018/020 | Batch 1100/1272 | Gen/Dis Loss: 7.7505/0.0043
# Epoch: 018/020 | Batch 1200/1272 | Gen/Dis Loss: 6.8602/0.0088
# Time elapsed: 42.49 min
# Epoch: 019/020 | Batch 000/1272 | Gen/Dis Loss: 9.1835/0.0112
# Epoch: 019/020 | Batch 100/1272 | Gen/Dis Loss: 8.6692/0.0061
# Epoch: 019/020 | Batch 200/1272 | Gen/Dis Loss: 2.0385/0.4838
# Epoch: 019/020 | Batch 300/1272 | Gen/Dis Loss: 7.7832/0.0136
# Epoch: 019/020 | Batch 400/1272 | Gen/Dis Loss: 6.3458/0.0253
# Epoch: 019/020 | Batch 500/1272 | Gen/Dis Loss: 18.0369/0.0058
# Epoch: 019/020 | Batch 600/1272 | Gen/Dis Loss: 10.3097/0.0299
# Epoch: 019/020 | Batch 700/1272 | Gen/Dis Loss: 6.7699/0.0081
# Epoch: 019/020 | Batch 800/1272 | Gen/Dis Loss: 8.5112/0.0070
# Epoch: 019/020 | Batch 900/1272 | Gen/Dis Loss: 7.5688/0.0097
# Epoch: 019/020 | Batch 1000/1272 | Gen/Dis Loss: 7.4352/0.0087
# Epoch: 019/020 | Batch 1100/1272 | Gen/Dis Loss: 15.6109/0.0129
# Epoch: 019/020 | Batch 1200/1272 | Gen/Dis Loss: 8.3607/0.0142
# Time elapsed: 44.84 min
# Epoch: 020/020 | Batch 000/1272 | Gen/Dis Loss: 7.9211/0.0027
# Epoch: 020/020 | Batch 100/1272 | Gen/Dis Loss: 7.0417/0.0048
# Epoch: 020/020 | Batch 200/1272 | Gen/Dis Loss: 8.3437/0.0134
# Epoch: 020/020 | Batch 300/1272 | Gen/Dis Loss: 7.6873/0.0039
# Epoch: 020/020 | Batch 400/1272 | Gen/Dis Loss: 10.5452/0.0186
# Epoch: 020/020 | Batch 500/1272 | Gen/Dis Loss: 12.2294/0.0359
# Epoch: 020/020 | Batch 600/1272 | Gen/Dis Loss: 7.0932/0.0039
# Epoch: 020/020 | Batch 700/1272 | Gen/Dis Loss: 9.4702/0.0169
# Epoch: 020/020 | Batch 800/1272 | Gen/Dis Loss: 7.3733/0.0273
# Epoch: 020/020 | Batch 900/1272 | Gen/Dis Loss: 7.9343/0.0193
# Epoch: 020/020 | Batch 1000/1272 | Gen/Dis Loss: 7.2864/0.0210
# Epoch: 020/020 | Batch 1100/1272 | Gen/Dis Loss: 8.0595/0.0363
# Epoch: 020/020 | Batch 1200/1272 | Gen/Dis Loss: 8.6924/0.0025
# Time elapsed: 47.19 min
# Total Training Time: 47.19 min

# %% [markdown]
# ## Evaluation

# %%
plot_multiple_training_losses(
    losses_list=(log_dict['train_discriminator_loss_per_batch'],
                 log_dict['train_generator_loss_per_batch']),
    num_epochs=NUM_EPOCHS, 
    custom_labels_list=(' -- Discriminator', ' -- Generator')
)

# %%
##########################
### VISUALIZATION
##########################

for i in range(0, NUM_EPOCHS, 5):
    
    plt.figure(figsize=(8, 8))
    plt.axis('off')
    plt.title(f'Generated images at epoch {i}')
    plt.imshow(np.transpose(log_dict['images_from_noise_per_epoch'][i], (1, 2, 0)))
    plt.show()
    
    
plt.figure(figsize=(8, 8))
plt.axis('off')
plt.title(f'Generated images after last epoch')
plt.imshow(np.transpose(log_dict['images_from_noise_per_epoch'][-1], (1, 2, 0)))
plt.show()
